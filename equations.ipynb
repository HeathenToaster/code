# %%
import matplotlib.pyplot as plt
import numpy as np
from ipywidgets import interact

# %%
def reward(alpha, gamma, mvtT):
    return alpha/(1+gamma * mvtT)
def effort(a, mass, mvtT, b, dist, gamma, i, j):
    return (a*mass*mvtT + ((b*mass*dist**i) / (mvtT**(j-1)))) / (1+(gamma*mvtT))
def effortwalk(a, mass, mvtT, b, dist, gamma):
    return (a*mass*mvtT + ((b*mass*dist**2) / (mvtT))) / (1+(gamma*mvtT))

# %%
T = np.linspace(0, 1, 100)

# %% [markdown]
# $$
#   Reward = \frac{\alpha} {1+\gamma*T}
# $$
# $$
#   Effort = -\frac{amT + \frac{bmd²}{T}}{1+\gamma*T}
# $$

# %%
fig = plt.figure(constrained_layout = False, figsize=(5, 5))
plt.plot(T, reward(0.5, 1, T), color = 'c')
plt.plot(T, -effort(a=15, mass=2, mvtT=T, b=77, dist=0.1, gamma=1, i=1.1, j=2.7)/1000, color = 'r')
plt.plot(T, (reward(alpha=0.5, gamma=1, mvtT=T) - effort(a=15, mass=2, mvtT=T, b=77, dist=.1, gamma=1, i=1.1, j=2.7)/1000), color='k')
plt.xlim(0.1, 1)
plt.ylim(-1,1)
plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
# Out:
# /home/david/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.
# /home/david/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.

# %%
fig = plt.figure(constrained_layout = False, figsize=(5, 5))
plt.plot(T, 0.5 - reward(0.5, 1, T), color = 'c')
plt.plot(T, effort(a=15, mass=2, mvtT=T, b=77, dist=0.1, gamma=1, i=1.1, j=2.7)/1000, color = 'r')
plt.plot(T, (.5-reward(alpha=0.5, gamma=1, mvtT=T) + effort(a=15, mass=2, mvtT=T, b=77, dist=.1, gamma=1, i=1.1, j=2.7)/1000), color='k')
plt.xlim(0.0, 1)
plt.ylim(0,1)
plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
# Out:
# /home/david/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.
# /home/david/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.

# %%
#increased reward
fig = plt.figure(constrained_layout = False, figsize=(5, 5))
Y1 = reward(alpha=1, gamma=1, mvtT=T) - effort(a=15, mass=2, mvtT=T, b=77, dist=.1, gamma=1, i=1.1, j=2.7)/1000
Y2 = reward(alpha=0.5, gamma=1, mvtT=T) - effort(a=15, mass=2, mvtT=T, b=77, dist=.1, gamma=1, i=1.1, j=2.7)/1000
plt.plot(T, Y1, color='g')
plt.plot(T, Y2, color='k')

plt.scatter(T[np.argmax(Y1)], Y1[np.argmax(Y1)], c='g')
plt.scatter(T[np.argmax(Y2)], Y2[np.argmax(Y2)], c='k')
plt.xlim(0.1, 1)
plt.ylim(-1,1)
plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
# Out:
# /home/david/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.

# %%
#increased mass
fig = plt.figure(constrained_layout = False, figsize=(5, 5))
Y1 = reward(alpha=0.5, gamma=1, mvtT=T) - effort(a=15, mass=2, mvtT=T, b=77, dist=.1, gamma=1, i=1.1, j=2.7)/1000
Y2 = reward(alpha=0.5, gamma=1, mvtT=T) - effort(a=15, mass=3, mvtT=T, b=77, dist=.1, gamma=1, i=1.1, j=2.7)/1000
plt.plot(T, Y1, color='g')
plt.plot(T, Y2, color='k')

plt.scatter(T[np.argmax(Y1)], Y1[np.argmax(Y1)], c='g')
plt.scatter(T[np.argmax(Y2)], Y2[np.argmax(Y2)], c='k')
plt.xlim(0.1, 1)
plt.ylim(-1,1)
plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
# Out:
# /home/david/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.

# %%
#increased time sensitivity
fig = plt.figure(constrained_layout = False, figsize=(5, 5))

Y1 = reward(alpha=0.5, gamma=1, mvtT=T) - effort(a=15, mass=2, mvtT=T, b=77, dist=.1, gamma=1, i=1.1, j=2.7)/1000
Y2 = reward(alpha=0.5, gamma=2, mvtT=T) - effort(a=15, mass=2, mvtT=T, b=77, dist=.1, gamma=2, i=1.1, j=2.7)/1000
plt.plot(T, Y1, color='g')
plt.plot(T, Y2, color='k')

plt.scatter(T[np.argmax(Y1)], Y1[np.argmax(Y1)], c='g')
plt.scatter(T[np.argmax(Y2)], Y2[np.argmax(Y2)], c='k')
plt.xlim(0.1, 1)
plt.ylim(-1,1)
plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
# Out:
# /home/david/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.

# %%
#increased reward
fig = plt.figure(constrained_layout = False, figsize=(5, 5))

def alphaslider(a): return a

alpha = 0.5
gamma = 1
mvtT  = T

a = 15
b = 77
mass = 0.4
dist = .1

Y1 = reward(alpha=alpha, gamma=gamma, mvtT=mvtT) - effortwalk(a=a, mass=mass, mvtT=mvtT, b=b, dist=dist, gamma=gamma)/1000
Y2 = reward(alpha=0.5, gamma=1, mvtT=T) - effortwalk(a=15, mass=2, mvtT=T, b=77, dist=.1, gamma=1)/1000
plt.plot(T, Y1, color='g')
plt.plot(T, Y2, color='k')

plt.scatter(T[np.argmax(Y1)], Y1[np.argmax(Y1)], c='g')
plt.scatter(T[np.argmax(Y2)], Y2[np.argmax(Y2)], c='k')
plt.xlim(0, 1)
plt.ylim(-1,1)
plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
# Out:
# /home/david/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in true_divide

# %%
# %matplotlib inline
from ipywidgets import interactive


Y2 = reward(alpha=0.5, gamma=1, mvtT=T) - effortwalk(a=15, mass=2, mvtT=T, b=77, dist=.1, gamma=1)/1000

def f(a, b, alpha, gamma, mass, dist):
    plt.figure(2)
    T = np.linspace(0, 1, 100)
    Y = alpha/(1+gamma*T) - (a*mass*T + ((b*mass*dist**2) / (T))) / (1+(gamma*T))/1000
    plt.plot(T, Y)
    plt.scatter(T[np.argmax(Y)], Y[np.argmax(Y)], c='k')
    plt.ylim(-1, 1)
    plt.xlim(0, 1)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()

interactive_plot = interactive(f, a=(15), b=(77), alpha=(0, 5.0), gamma=(0, 5, 0.5), mass=(0, 1.0), dist=(0, 2, 0.1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# /home/david/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in true_divide
# interactive(children=(IntSlider(value=15, description='a', max=45, min=-15), IntSlider(value=77, description='…

# %%
#Y2 = reward(alpha=0.5, gamma=1, mvtT=T) - effortwalk(a=15, mass=2, mvtT=T, b=77, dist=.1, gamma=1)/1000
from ipywidgets import interactive

def v(Vmoy, t_0, t_1, mu, sigma, y):
    plt.figure(1)
    T = np.linspace(0.01, 2.5, 500)
    Y = ((Vmoy * (t_1 - t_0)) / (sigma * np.sqrt(2*np.pi) * (T - t_0))) * np.exp(-((np.log((T-t_0)/(t_1-t_0))-mu)**2 ) / (2*sigma**2))
    dY = ((Vmoy * (t_1 - t_0)) * (np.exp(-(((np.log((T-t_0)/(t_1-t_0))-mu)**2 )* 1/(2*sigma**2)))) * (np.log((T-t_0)/(t_1-t_0)) + sigma**2 - mu)) / ((sigma**3) * np.sqrt(2*np.pi) * (T-t_0)**2)
    tVmax = t_0 + np.exp(mu - sigma ** 2) * (t_1-t_0)
    Ymax = ((Vmoy * (t_1 - t_0)) / (sigma * np.sqrt(2*np.pi) * (tVmax - t_0))) * np.exp(-(((np.log((tVmax-t_0)/(t_1-t_0))-mu)**2 )* 1/(2*sigma**2)))
    #print(Ymax)
    plt.plot(T, Y)
    plt.plot(T[Y>15], Y[Y>15], lw = 2)
    #print(T[Y>15], Y[Y>15])

    plt.plot(T, dY, lw=0.5)
    plt.plot((tVmax, tVmax), (-10, 150), color='k', lw=0.5)


    #print((t_1-t_0)/(y*sigma * np.sqrt(2*np.pi)))
    plt.scatter((t_1-t_0)/(y*sigma * np.sqrt(2*np.pi)), 1)

    plt.ylim(0, 120)
    plt.xlim(0, 2.5)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()

interactive_plot = interactive(v, Vmoy=(0, 120, 1), t_0=(0.0), t_1=(0,2.0), mu=(-2,0,0.1), sigma=(0.05, 1, 0.05), y=(0, 10, 1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(IntSlider(value=60, description='Vmoy', max=120), FloatSlider(value=0.0, description='t_…

# %%
#Y2 = reward(alpha=0.5, gamma=1, mvtT=T) - effortwalk(a=15, mass=2, mvtT=T, b=77, dist=.1, gamma=1)/1000
from ipywidgets import interactive

def v(Vmoy, t_0, t_1, mu, sigma, y):
    plt.figure(1)
    T = np.linspace(0.01, 2.5, 500)
    Y = ((Vmoy * (t_1 - t_0)) / (sigma * np.sqrt(2*np.pi) * (T - t_0))) * np.exp(-((np.log((T-t_0)/(t_1-t_0))-mu)**2 ) / (2*sigma**2))
    dY = ((Vmoy * (t_1 - t_0)) * (np.exp(-(((np.log((T-t_0)/(t_1-t_0))-mu)**2 )* 1/(2*sigma**2)))) * (np.log((T-t_0)/(t_1-t_0)) + sigma**2 - mu)) / ((sigma**3) * np.sqrt(2*np.pi) * (T-t_0)**2)
    tVmax = t_0 + np.exp(mu - sigma ** 2) * (t_1-t_0)
    Ymax = ((Vmoy * (t_1 - t_0)) / (sigma * np.sqrt(2*np.pi) * (tVmax - t_0))) * np.exp(-(((np.log((tVmax-t_0)/(t_1-t_0))-mu)**2 )* 1/(2*sigma**2)))
    print(Ymax)
    plt.plot(T, Y)
    plt.plot(T[Y>15], Y[Y>15], lw = 2)
    #print(T[Y>15], Y[Y>15])
    plt.scatter(t_0 + y/(sigma * np.sqrt(2*np.pi)), 0.1)
    print(t_0 + y/(sigma * np.sqrt(2*np.pi)))

    plt.plot(T, dY, lw=0.5)
    plt.plot((tVmax, tVmax), (-10, 150), color='k', lw=0.5)


    plt.ylim(0, 120)
    plt.xlim(0, 2.5)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()

interactive_plot = interactive(v, Vmoy=(0, 120, 1), t_0=(0.0), t_1=(0,2.0), mu=(-2,0,0.5), sigma=(0.05, 1, 0.05), y=(0, 10, 1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(IntSlider(value=60, description='Vmoy', max=120), FloatSlider(value=0.0, description='t_…

# %%
# The Coordination of Arm Movements: An Experimentally Confirmed Mathematical Model
# FLASH & HOGAN, 1985

from ipywidgets import interactive

def vtest2(x_0 = 0, x_f= 95, tf=1.5):
    plt.figure(1)
    T = np.linspace(0, tf, 500)

    Y = x_0 + (x_0 - x_f)*((15 * (T/tf) **4)-(6 * (T/tf) **5)-(10 * (T/tf) **3))
    dY = ((x_0-x_f) * (-30*T**2)*(T-tf)**2)/(tf**5)
    ddY = ((-60*T)*(x_0-x_f) * (2*T**2 - 3*T*tf + tf**2))/(tf**5)


    plt.plot(T, Y)
    plt.plot(T, dY)
    plt.plot(T, ddY/10)

    plt.scatter(tf/2, (-15*(x_0-x_f))/(8*tf))

    plt.ylim(-50, 150)
    plt.xlim(0, 5)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()

interactive_plot = interactive(vtest2, x_0=(0, 120, 1), x_f=(0, 120, 1), tf=(0, 5.0, .1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(IntSlider(value=0, description='x_0', max=120), IntSlider(value=95, description='x_f', m…

# %%
# Analytical model of m–S curve using generalized skewed-parabola
# Naoshi Miyashita a , Tetsuji Kawazura a , Kazuyuki Kabe b
# Advanced Materials Laboratory, Research & Development Center, Yokohama Rubber Co., Ltd., 2-1, Oiwake, Hi

def v(vMax=1, n=2, q=0, tf=2):
    plt.figure(1)
    T = np.linspace(0, tf, 201)
    
    tf=2/tf

    Y = vMax*(1 - np.abs(tf*T - 1)**n) * (1 - q * (tf*T - 1))


    #dYY = ((vMax*tf*n *(1-q*(tf*T-1)) * np.abs(tf*T-1)**n)/(tf*T-1)) - vMax* tf * q* (1-np.abs(tf*T-1)**n)
    #dYY = (2*(-q + (n*(-2*T + tf)*(-2*q*T + tf + q*tf) * np.abs(1 - (2*T)/tf)**(-2 + n))/tf**2 + q*np.abs(1 - (2*T)/tf)**n))/tf
    dYY = n*tf*(-1 + T*tf)*(-1 - q + q*T*tf) *np.abs(-1 + T*tf)**(-2 + n) + q *tf* (-1 + np.abs(-1 + T*tf)**n)
    
    plt.plot(T, Y)
    plt.plot(T, dYY)


    plt.ylim(-2, 2)
    plt.xlim(0, 5)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()

interactive_plot = interactive(v, vMax=(0, 2,.1), n=(0, 10, 1), q=(-1, 1, 0.1), tf=(0, 5, .1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=1.0, description='vMax', max=2.0), IntSlider(value=2, description='n',…

# %%
# Analytical model of m–S curve using generalized skewed-parabola
# Naoshi Miyashita a , Tetsuji Kawazura a , Kazuyuki Kabe b
# Advanced Materials Laboratory, Research & Development Center, Yokohama Rubber Co., Ltd., 2-1, Oiwake, Hi
from ipywidgets import interactive

def v(vMax=1, n=2, q=0, tf=2):
    plt.figure(1)
    T = np.linspace(-25, 25, 201)
    
    tf=2/tf

    Y = vMax*(1 - (tf*T - 1)**n) * (1 - q * (tf*T - 1))
    dYY = vMax*tf*n* (tf*T - 1)**(n-1) * (q * (tf*T - 1)-1) + tf*q*((tf*T - 1)**n-1)
    dYY = vMax*tf*n* (tf*T - 1)**(n-1) * (q * (tf*T - 1)-1) + tf*q*((tf*T - 1)**n-1)
    
    plt.plot(T, Y)
    plt.plot(T, dYY)

    plt.ylim(-25, 25)
    plt.xlim(-25, 25)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()

interactive_plot = interactive(v, vMax=(0, 2,.1), n=(0, 10, 1), q=(-1, 1, 0.1), tf=(0, 5, .1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=1.0, description='vMax', max=2.0), IntSlider(value=2, description='n',…

# %%
 
def calc_parabola_vertex(x1, y1, x2, y2, x3, y3):
    denom = (x1-x2) * (x1-x3) * (x2-x3);
    A     = (x3 * (y2-y1) + x2 * (y1-y3) + x1 * (y3-y2)) / denom;
    B     = (x3*x3 * (y1-y2) + x2*x2 * (y3-y1) + x1*x1 * (y2-y3)) / denom;
    C     = (x2 * x3 * (x2-x3) * y1+x3 * x1 * (x3-x1) * y2+x1 * x2 * (x1-x2) * y3) / denom;
    return A,B,C


from ipywidgets import interactive

def v(Vmax, tf):
    plt.figure(1)
    x1,y1=[0,0]
    x2,y2=[tf,0]
    x3,y3=[tf/2,Vmax]

    a,b,c=calc_parabola_vertex(x1, y1, x2, y2, x3, y3)
    x_pos=np.linspace(0,tf,100)
    y_pos=[]

    #Calculate y values 
    for x in range(len(x_pos)):
        x_val=x_pos[x]
        y=(a*(x_val**2))+(b*x_val)+c
        y_pos.append(y)

    print("y=", a, "x**2 + ", b, "x +", c)
    plt.plot(x_pos, y_pos, linestyle='-.', color='black') # parabola line
    plt.scatter(x_pos, y_pos, color='gray') # parabola points
    plt.scatter(x1,y1,color='r',marker="D",s=50) # 1st known xy
    plt.scatter(x2,y2,color='g',marker="D",s=50) # 2nd known xy
    plt.scatter(x3,y3,color='k',marker="D",s=50) # 3rd known xy
    plt.xlim(0, 5)
    plt.ylim(0, 150)
    plt.show() 


interactive_plot = interactive(v, Vmax=(0, 100, 10), tf=(0, 5.0))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(IntSlider(value=50, description='Vmax', step=10), FloatSlider(value=2.5, description='tf…

# %%
 
def calc_parabola_vertex(x1, y1, x2, y2, x3, y3):
    denom = (x1-x2) * (x1-x3) * (x2-x3);
    A     = (x3 * (y2-y1) + x2 * (y1-y3) + x1 * (y3-y2)) / denom;
    B     = (x3*x3 * (y1-y2) + x2*x2 * (y3-y1) + x1*x1 * (y2-y3)) / denom;
    C     = (x2 * x3 * (x2-x3) * y1+x3 * x1 * (x3-x1) * y2+x1 * x2 * (x1-x2) * y3) / denom;
    return A,B,C
tf=1.5
x1,y1=[0,0]
x2,y2=[tf,0]
x3,y3=[tf/2,100]

#Calculate the unknowns of the equation y=ax^2+bx+c
a,b,c=calc_parabola_vertex(x1, y1, x2, y2, x3, y3)

x_pos=np.linspace(-5,5,100)
y_pos=[]

#Calculate y values 
for x in range(len(x_pos)):
    x_val=x_pos[x]
    y=(a*(x_val**2))+(b*x_val)+c
    y_pos.append(y)
print("y=", a, "x**2 + ", b, "x +", c)
plt.plot(x_pos, y_pos, linestyle='-.', color='black') # parabola line
plt.scatter(x_pos, y_pos, color='gray') # parabola points
plt.scatter(x1,y1,color='r',marker="D",s=50) # 1st known xy
plt.scatter(x2,y2,color='g',marker="D",s=50) # 2nd known xy
plt.scatter(x3,y3,color='k',marker="D",s=50) # 3rd known xy
plt.xlim(0, 2)
plt.ylim(0, 150)
plt.show()
# Out:
# y= -177.77777777777777 x**2 +  266.6666666666667 x + 0.0

# %%
# optimal time computation

from ipywidgets import interactive

def v(d=60, Vbelt=0, Vopt=60):


    tf = (d/Vopt) * (1 - 0.5*((Vbelt**2)/(Vopt**2)))
    print(tf)

    plt.figure(1)
    T = np.linspace(-1000, 1000, 2001)
    
    tf=2/tf

    dY = ((-d**2)/(T**2)) + Vbelt**2
    Y = ((d**2)/T) -2* Vbelt*d + T*Vbelt**2
    
    plt.plot(T, Y, label='mvt cost')
    plt.plot(T, dY)
    plt.legend()
    plt.ylim(-500, 500)
    plt.xlim(-0, 150)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()
    


interactive_plot = interactive(v, d=(0, 100, 1), Vbelt=(-20, 20, 1), Vopt=(30, 100, 1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(IntSlider(value=60, description='d'), IntSlider(value=0, description='Vbelt', max=20, mi…

# %%
# optimal time computation

from ipywidgets import interactive

def v(d=60, Vbelt=0, Vopt=60):


    tf = (d/Vopt) * (1 - 0.5*((Vbelt**2)/(Vopt**2)))
    print(tf)

    plt.figure(1)
    T = np.linspace(-1000, 1000, 2001)
    
    tf=2/tf

    
    Y = ((d**2)/T) -2* Vbelt*d + T*Vbelt**2
    dY = ((-d**2)/(T**2)) + Vbelt**2

    
    plt.plot(T, Y, label='mvt cost')
    plt.plot(T, dY)
    plt.legend()
    plt.ylim(-500, 500)
    plt.xlim(-0, 150)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()
    


interactive_plot = interactive(v, d=(0, 100, 1), Vbelt=(-20, 20, 1), Vopt=(30, 100, 1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(IntSlider(value=60, description='d'), IntSlider(value=0, description='Vbelt', max=20, mi…

# %%
from ipywidgets import interactive

def v(R=1, B=2):
    plt.figure(1)
    T = np.linspace(0, 25, 201)


    Y = R - (R/(1+B*T))
    dYY = (B*R)/((1+B*T)**2)
    
    plt.plot(T, Y)
    plt.plot(T, dYY)

    plt.ylim(0, 25)
    plt.xlim(0, 25)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.axhline(y=R, xmin=0, xmax = 25, ls='--', color='k', lw=0.5)
    plt.show()

interactive_plot = interactive(v, R=(0, 20,.1), B=(0, 10, .1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=1.0, description='R', max=20.0), FloatSlider(value=2.0, description='B…

# %%
# optimal time computation

from ipywidgets import interactive

def v(d=.9, Vbelt=0, alpha = 1, beta = 1):


    # tf = (d/Vopt) * (1 - 0.5*((Vbelt**2)/(Vopt**2)))
    # print(tf)
    fig = plt.figure(constrained_layout = False, figsize=(7.5, 4.5))
    plt.figure(1)
    T = np.linspace(0.01, 2.5, 201)

    mvt = (alpha*d**2)/T -2*alpha*d*Vbelt + alpha*T*Vbelt**2
    time = beta*T**3
    
    dmvt = (-alpha*d**2)/T**2 + alpha*Vbelt**2
    dtime = 3*beta*T**2

    
    plt.plot(T, mvt, label='mvt cost', color='r')
    plt.plot(T, dmvt, label='dmvt cost', color='r', alpha = 0.25)

    plt.plot(T, time, label='time cost', color='g')
    plt.plot(T, dtime, label='dtime cost', color='g', alpha = 0.25)

    plt.plot(T, mvt + time, label='total cost', color='k')
    plt.plot(T, dmvt + dtime, label='dtotal cost', color='k', alpha = 0.25)

    # tf = np.sqrt((-alpha*Vbelt**2 + np.sqrt(alpha**2 * Vbelt**4 + 12*alpha*beta*d**2))/(6*beta))
    # print("tf", tf)
    # plt.axvline(tf, 0, 1, ls='--', color='k', lw=0.5)


    Vopt = np.sqrt(np.sqrt((3*beta*d**2)/alpha))
    print("Vopt", Vopt)


    tf3 = d/Vopt*(1-0.25*Vbelt**2/Vopt**2)
    print("approxtf", tf3)
    plt.axvline(tf3, 0, 1, ls='--', color='c', lw=0.5)

    plt.legend()
    plt.ylim(0, 25)
    plt.xlim(0, 2.5)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()
    


interactive_plot = interactive(v, d=(.30, .9, .3), Vbelt=(-0.20, .20, .10), alpha=(1, 10, 1), beta=(1, 10, 1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=0.9, description='d', max=0.9, min=0.3, step=0.3), FloatSlider(value=0…

# %%
# optimal time computation

from ipywidgets import interactive

def v(d=.9, Vbelt=0, alpha = 1, beta = 1, R=1):


    # tf = (d/Vopt) * (1 - 0.5*((Vbelt**2)/(Vopt**2)))
    # print(tf)
    fig = plt.figure(constrained_layout = False, figsize=(7.5, 4.5))
    plt.figure(1)
    T = np.linspace(0.01, 2.5, 201)

    mvt = (alpha*d**2)/T -2*alpha*d*Vbelt + alpha*T*Vbelt**2
    time3 = beta*T**3
    time1 = beta*T
    
    dmvt = (-alpha*d**2)/T**2 + alpha*Vbelt**2
    dtime3 = 3*beta*T**2
    dtime1 = beta*T

    Y = R - (R/(1+beta*T))
    dYY = (beta*R)/((1+beta*T)**2)
    
    plt.plot(T, Y)
    #plt.plot(T, dYY)
    
    plt.plot(T, mvt, label='mvt cost', color='r')
    plt.plot(T, dmvt, label='dmvt cost', color='r', alpha = 0.25)

    plt.plot(T, time3, label='time cost', color='g')
    plt.plot(T, dtime3, label='dtime cost', color='g', alpha = 0.25)

    plt.plot(T, time1, label='total cost', color='k')
    plt.plot(T, dtime1, label='dtotal cost', color='k', alpha = 0.25)



    plt.legend()
    plt.ylim(0, 25)
    plt.xlim(0, 2.5)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()
    


interactive_plot = interactive(v, d=(.30, .9, .3), Vbelt=(-0.20, .20, .10), alpha=(1, 10, 1), beta=(1, 10, 1), R=(1, 100, 1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=0.9, description='d', max=0.9, min=0.3, step=0.3), FloatSlider(value=0…

# %%
from ipywidgets import interactive

def v(alpha=1, R=1, B=2, d=.9, Vbelt=0):
    plt.figure(1)
    T = np.linspace(-100, 100, 2001)


    Y = R - (R/(1+B*T))
    dYY = B*R/((1+B*T)**2)
    



    mvt = (alpha*d**2)/T -2*alpha*d*Vbelt + alpha*T*Vbelt**2
    dmvt = (-alpha*d**2)/T**2 + alpha*Vbelt**2


    # plt.plot(T, Y)
    # plt.plot(T, dYY)
    #plt.plot(T, mvt)
    # plt.plot(T, dmvt)

    #plt.plot(T, Y+mvt, c='k')
    plt.plot(T, dYY+dmvt, c='k')

    # AY = R - (R/(1+B*T))
    # AdYY = (B*R)/((1+B*T)**2)
    # plt.plot(T, AY, c='r')
    # plt.plot(T, AdYY, c='r')

    plt.ylim(-25, 25)
    plt.xlim(-25, 25)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.axhline(y=R, xmin=0, xmax = 25, ls='--', color='k', lw=0.5)
    plt.show()

interactive_plot = interactive(v, R=(0, 20,.1), B=(0, 10, .1), d=(.30, .9, .3), Vbelt=(-0.20, .20, .10))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(IntSlider(value=1, description='alpha', max=3, min=-1), FloatSlider(value=1.0, descripti…

# %%
# optimal time computation


from ipywidgets import interactive

#def v(d=.9, Vbelt=0, alpha = 1, beta = 1, R=1):

def v(d=.9, Vbelt=0, alpha = 1, beta = 1, R=1):


    # tf = (d/Vopt) * (1 - 0.5*((Vbelt**2)/(Vopt**2)))
    # print(tf)
    fig = plt.figure(constrained_layout = False, figsize=(7.5, 4.5))
    plt.figure(1)
    T = np.linspace(0.01, 2.5, 201)

    mvt = (alpha*(d**2))/T -2*alpha*d*Vbelt + alpha*T*Vbelt**2
    # time3 = R - 1/(beta*T)
    
    dmvt = (-alpha*(d**2))/T**2 + alpha*Vbelt**2
    # dtime3 = -R/(beta*T**2)

    time3 = R - (R/(1+beta*T))
    dtime3 = (beta*R)/((1+beta*T)**2)


    plt.plot(T, mvt, label='mvt cost', color='r')
    plt.plot(T, dmvt, label='dmvt cost', color='r', alpha = 0.25)

    plt.plot(T, time3, label='time cost', color='g')
    plt.plot(T, dtime3, label='dtime cost', color='g', alpha = 0.25)

    plt.plot(T, mvt+time3, label='total cost', color='k')
    plt.plot(T, dmvt+dtime3, label='dtotal cost', color='c')

    a=alpha
    b=beta
    #tttf = np.sqrt(R)*np.sqrt(a)*d/(np.sqrt(b)*(R - a*b*d**2)) - a*d**2/(-R + a*b*d**2)
    #print(tttf)
    #plt.axvline(tttf, 0, 1, ls='--', color='c', lw=0.5)
    print("R=", R, "thingy=", alpha*beta*d**2)


    plt.legend()
    plt.ylim(-5, 100)
    plt.xlim(0, 2.5)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()
    


interactive_plot = interactive(v, d=(.30, .9, .3), Vbelt=(-0.20, .20, .10), alpha=(1, 10, 1), beta=(1, 10, 1), R=(1, 100, 1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=0.9, description='d', max=0.9, min=0.3, step=0.3), FloatSlider(value=0…

# %%
# optimal time computation


from ipywidgets import interactive

#def v(d=.9, Vbelt=0, alpha = 1, beta = 1, R=1):

def v(d=.9, Vbelt=0, alpha = 1, beta = 1, R=1):


    # tf = (d/Vopt) * (1 - 0.5*((Vbelt**2)/(Vopt**2)))
    # print(tf)
    fig = plt.figure(constrained_layout = False, figsize=(7.5, 4.5))
    plt.figure(1)
    T = np.linspace(0.01, 2.5, 201)

    mvt = (alpha*(d**2))/T -2*alpha*d*Vbelt + alpha*T*Vbelt**2
    # time3 = R - 1/(beta*T)
    
    dmvt = (-alpha*(d**2))/T**2 + alpha*Vbelt**2
    # dtime3 = -R/(beta*T**2)

    time3 = R - (R/(1+beta*T))
    dtime3 = (beta*R)/((1+beta*T)**2)


    plt.plot(T, mvt+time3, label='total cost', color='k')
    plt.plot(T, dmvt+dtime3, label='dtotal cost', color='c')

    a=alpha
    b=beta
    #tttf = np.sqrt(R)*np.sqrt(a)*d/(np.sqrt(b)*(R - a*b*d**2)) - a*d**2/(-R + a*b*d**2)
    #print(tttf)
    #plt.axvline(tttf, 0, 1, ls='--', color='c', lw=0.5)
    print("R=", R, "thingy=", alpha*beta*d**2)


    plt.legend()
    plt.ylim(-5, 100)
    plt.xlim(0, 2.5)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()
    


interactive_plot = interactive(v, d=(.30, .9, .3), Vbelt=(-0.20, .20, .10), alpha=(1, 10, 1), beta=(1, 10, 1), R=(1, 100, 1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=0.9, description='d', max=0.9, min=0.3, step=0.3), FloatSlider(value=0…

# %%
0<r<a*b*d^2
v<-sqrt((a^3 b^2 d^2 - a^2 b r)/a^3 + (3 (a^8 (-b^5) d^4 r + a^7 b^4 d^2 r^2 + sqrt(a^16 b^10 d^8 r^2 + 2 a^15 b^9 d^6 r^3 + a^14 b^8 d^4 r^4))^(1/3))/(2^(1/3) a^3) - (3 2^(1/3) a^2 b^3 d^2 r)/(a^8 (-b^5) d^4 r + a^7 b^4 d^2 r^2 + sqrt(a^16 b^10 d^8 r^2 + 2 a^15 b^9 d^6 r^3 + a^14 b^8 d^4 r^4))^(1/3)), x = -1/2 sqrt((2^(1/3) (a b^2 d^2 - a v^2 - b r)^2)/(3 a b^2 v^2 (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)) - (2 (-a b^2 d^2 + a v^2 + b r))/(3 a b^2 v^2) + (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)/(3 2^(1/3) a b^2 v^2) + 1/b^2) + 1/2 sqrt(-(2^(1/3) (a b^2 d^2 - a v^2 - b r)^2)/(3 a b^2 v^2 (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)) - (4 (-a b^2 d^2 + a v^2 + b r))/(3 a b^2 v^2) - (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)/(3 2^(1/3) a b^2 v^2) - ((16 d^2)/(b v^2) + (8 (-a b^2 d^2 + a v^2 + b r))/(a b^3 v^2) - 8/b^3)/(4 sqrt((2^(1/3) (a b^2 d^2 - a v^2 - b r)^2)/(3 a b^2 v^2 (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)) - (2 (-a b^2 d^2 + a v^2 + b r))/(3 a b^2 v^2) + (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)/(3 2^(1/3) a b^2 v^2) + 1/b^2)) + 2/b^2) - 1/(2 b)
 -sqrt((a^3 b^2 d^2 - a^2 b r)/a^3 + (3 (a^8 (-b^5) d^4 r + a^7 b^4 d^2 r^2 + sqrt(a^16 b^10 d^8 r^2 + 2 a^15 b^9 d^6 r^3 + a^14 b^8 d^4 r^4))^(1/3))/(2^(1/3) a^3) - (3 2^(1/3) a^2 b^3 d^2 r)/(a^8 (-b^5) d^4 r + a^7 b^4 d^2 r^2 + sqrt(a^16 b^10 d^8 r^2 + 2 a^15 b^9 d^6 r^3 + a^14 b^8 d^4 r^4))^(1/3))<=v<0, x = 1/2 sqrt((2^(1/3) (a b^2 d^2 - a v^2 - b r)^2)/(3 a b^2 v^2 (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)) - (2 (-a b^2 d^2 + a v^2 + b r))/(3 a b^2 v^2) + (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)/(3 2^(1/3) a b^2 v^2) + 1/b^2) + 1/2 sqrt(-(2^(1/3) (a b^2 d^2 - a v^2 - b r)^2)/(3 a b^2 v^2 (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)) - (4 (-a b^2 d^2 + a v^2 + b r))/(3 a b^2 v^2) - (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)/(3 2^(1/3) a b^2 v^2) + ((16 d^2)/(b v^2) + (8 (-a b^2 d^2 + a v^2 + b r))/(a b^3 v^2) - 8/b^3)/(4 sqrt((2^(1/3) (a b^2 d^2 - a v^2 - b r)^2)/(3 a b^2 v^2 (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)) - (2 (-a b^2 d^2 + a v^2 + b r))/(3 a b^2 v^2) + (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)/(3 2^(1/3) a b^2 v^2) + 1/b^2)) + 2/b^2) - 1/(2 b)
0<v<=sqrt((a^3 b^2 d^2 - a^2 b r)/a^3 + (3 (a^8 (-b^5) d^4 r + a^7 b^4 d^2 r^2 + sqrt(a^16 b^10 d^8 r^2 + 2 a^15 b^9 d^6 r^3 + a^14 b^8 d^4 r^4))^(1/3))/(2^(1/3) a^3) - (3 2^(1/3) a^2 b^3 d^2 r)/(a^8 (-b^5) d^4 r + a^7 b^4 d^2 r^2 + sqrt(a^16 b^10 d^8 r^2 + 2 a^15 b^9 d^6 r^3 + a^14 b^8 d^4 r^4))^(1/3)), x = 1/2 sqrt((2^(1/3) (a b^2 d^2 - a v^2 - b r)^2)/(3 a b^2 v^2 (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)) - (2 (-a b^2 d^2 + a v^2 + b r))/(3 a b^2 v^2) + (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)/(3 2^(1/3) a b^2 v^2) + 1/b^2) + 1/2 sqrt(-(2^(1/3) (a b^2 d^2 - a v^2 - b r)^2)/(3 a b^2 v^2 (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)) - (4 (-a b^2 d^2 + a v^2 + b r))/(3 a b^2 v^2) - (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)/(3 2^(1/3) a b^2 v^2) + ((16 d^2)/(b v^2) + (8 (-a b^2 d^2 + a v^2 + b r))/(a b^3 v^2) - 8/b^3)/(4 sqrt((2^(1/3) (a b^2 d^2 - a v^2 - b r)^2)/(3 a b^2 v^2 (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)) - (2 (-a b^2 d^2 + a v^2 + b r))/(3 a b^2 v^2) + (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)/(3 2^(1/3) a b^2 v^2) + 1/b^2)) + 2/b^2) - 1/(2 b)
v>sqrt((a^3 b^2 d^2 - a^2 b r)/a^3 + (3 (a^8 (-b^5) d^4 r + a^7 b^4 d^2 r^2 + sqrt(a^16 b^10 d^8 r^2 + 2 a^15 b^9 d^6 r^3 + a^14 b^8 d^4 r^4))^(1/3))/(2^(1/3) a^3) - (3 2^(1/3) a^2 b^3 d^2 r)/(a^8 (-b^5) d^4 r + a^7 b^4 d^2 r^2 + sqrt(a^16 b^10 d^8 r^2 + 2 a^15 b^9 d^6 r^3 + a^14 b^8 d^4 r^4))^(1/3)), x = -1/2 sqrt((2^(1/3) (a b^2 d^2 - a v^2 - b r)^2)/(3 a b^2 v^2 (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)) - (2 (-a b^2 d^2 + a v^2 + b r))/(3 a b^2 v^2) + (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)/(3 2^(1/3) a b^2 v^2) + 1/b^2) + 1/2 sqrt(-(2^(1/3) (a b^2 d^2 - a v^2 - b r)^2)/(3 a b^2 v^2 (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)) - (4 (-a b^2 d^2 + a v^2 + b r))/(3 a b^2 v^2) - (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)/(3 2^(1/3) a b^2 v^2) - ((16 d^2)/(b v^2) + (8 (-a b^2 d^2 + a v^2 + b r))/(a b^3 v^2) - 8/b^3)/(4 sqrt((2^(1/3) (a b^2 d^2 - a v^2 - b r)^2)/(3 a b^2 v^2 (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)) - (2 (-a b^2 d^2 + a v^2 + b r))/(3 a b^2 v^2) + (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)/(3 2^(1/3) a b^2 v^2) + 1/b^2)) + 2/b^2) - 1/(2 b)

r=a*b*d^2
v>0, x = -sqrt(1/b^2 + v^2/(b^2 (54 b^4 d^4 v^2 + 6 sqrt(3) sqrt(27 b^8 d^8 v^4 + b^4 d^4 v^8) + v^6)^(1/3)) + (54 b^4 d^4 v^2 + 6 sqrt(3) sqrt(27 b^8 d^8 v^4 + b^4 d^4 v^8) + v^6)^(1/3)/(b^2 v^2))/(2 sqrt(3)) + 1/2 sqrt(2/(3 b^2) - (54 b^4 d^4 v^2 + 6 sqrt(3) sqrt(27 b^8 d^8 v^4 + b^4 d^4 v^8) + v^6)^(1/3)/(3 b^2 v^2) - v^2/(3 b^2 (54 b^4 d^4 v^2 + 6 sqrt(3) sqrt(27 b^8 d^8 v^4 + b^4 d^4 v^8) + v^6)^(1/3)) - (4 sqrt(3) d^2)/(b v^2 sqrt(1/b^2 + v^2/(b^2 (54 b^4 d^4 v^2 + 6 sqrt(3) sqrt(27 b^8 d^8 v^4 + b^4 d^4 v^8) + v^6)^(1/3)) + (54 b^4 d^4 v^2 + 6 sqrt(3) sqrt(27 b^8 d^8 v^4 + b^4 d^4 v^8) + v^6)^(1/3)/(b^2 v^2)))) - 1/(2 b)
v<0, x = -sqrt(1/b^2 + v^2/(b^2 (54 b^4 d^4 v^2 + 6 sqrt(3) sqrt(27 b^8 d^8 v^4 + b^4 d^4 v^8) + v^6)^(1/3)) + (54 b^4 d^4 v^2 + 6 sqrt(3) sqrt(27 b^8 d^8 v^4 + b^4 d^4 v^8) + v^6)^(1/3)/(b^2 v^2))/(2 sqrt(3)) + 1/2 sqrt(2/(3 b^2) - (54 b^4 d^4 v^2 + 6 sqrt(3) sqrt(27 b^8 d^8 v^4 + b^4 d^4 v^8) + v^6)^(1/3)/(3 b^2 v^2) - v^2/(3 b^2 (54 b^4 d^4 v^2 + 6 sqrt(3) sqrt(27 b^8 d^8 v^4 + b^4 d^4 v^8) + v^6)^(1/3)) - (4 sqrt(3) d^2)/(b v^2 sqrt(1/b^2 + v^2/(b^2 (54 b^4 d^4 v^2 + 6 sqrt(3) sqrt(27 b^8 d^8 v^4 + b^4 d^4 v^8) + v^6)^(1/3)) + (54 b^4 d^4 v^2 + 6 sqrt(3) sqrt(27 b^8 d^8 v^4 + b^4 d^4 v^8) + v^6)^(1/3)/(b^2 v^2)))) - 1/(2 b)

r>a*b*d^2

x = -1/2 sqrt((2^(1/3) (a b^2 d^2 - a v^2 - b r)^2)/(3 a b^2 v^2 (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)) - (2 (-a b^2 d^2 + a v^2 + b r))/(3 a b^2 v^2) + (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)/(3 2^(1/3) a b^2 v^2) + 1/b^2) + 1/2 sqrt(-(2^(1/3) (a b^2 d^2 - a v^2 - b r)^2)/(3 a b^2 v^2 (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)) - (4 (-a b^2 d^2 + a v^2 + b r))/(3 a b^2 v^2) - (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)/(3 2^(1/3) a b^2 v^2) - ((16 d^2)/(b v^2) + (8 (-a b^2 d^2 + a v^2 + b r))/(a b^3 v^2) - 8/b^3)/(4 sqrt((2^(1/3) (a b^2 d^2 - a v^2 - b r)^2)/(3 a b^2 v^2 (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)) - (2 (-a b^2 d^2 + a v^2 + b r))/(3 a b^2 v^2) + (108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3 + sqrt((108 a^3 b^4 v^2 d^4 - 108 a^3 b^2 v^4 d^2 + 108 a^2 b^2 v^2 (-a b^2 d^2 + a v^2 + b r) d^2 + 2 (-a b^2 d^2 + a v^2 + b r)^3)^2 - 4 (-a b^2 d^2 + a v^2 + b r)^6))^(1/3)/(3 2^(1/3) a b^2 v^2) + 1/b^2)) + 2/b^2) - 1/(2 b)
# Out:
#   File "/tmp/ipykernel_4260/3781400411.py", line 2
# ...

# %%
a=1
b=1
r=2
d=1
print(r, a*b*d*d)

aa = -a*b**2*d**2 + a*v**2 + b*r
bb = 108*a**3*b**4*v**2*d**4
cc = 108*a**3*b**2*v**4*d**2
dd = 3*a*b**2*v**2
ee = 108*a**2*b**2*v**2
x = (-1/2*np.sqrt((2**(1/3)*(a*b**2*d**2 - a*v**2 - b*r)**2)/(dd*(bb - cc + ee*(aa)*d**2 + 2*(aa)**3 + np.sqrt((bb - cc + ee*(aa)*d**2 + 2*(aa)**3)**2 - 4*(aa)**6))**(1/3)) - (2*(aa))/(dd) + (bb - cc + ee*(aa)*d**2 + 2*(aa)**3 + np.sqrt((bb - cc + ee*(aa)*d**2 + 2*(aa)**3)**2 - 4*(aa)**6))**(1/3)/(3*2**(1/3)*a*b**2*v**2)+ 1/b**2) + 1/2*np.sqrt(-(2**(1/3)*(a*b**2*d**2 - a*v**2 - b*r)**2)/(dd*(bb - cc + ee*(aa)*d**2 + 2*(aa)**3 + np.sqrt((bb - cc + ee*(aa)*d**2 + 2*(aa)**3)**2 - 4*(aa)**6))**(1/3)) - (4*(aa))/(dd) - (bb - cc + ee*(aa)*d**2 + 2*(aa)**3 + np.sqrt((bb - cc + ee*(aa)*d**2 + 2*(aa)**3)**2 - 4*(aa)**6))**(1/3)/(3*2**(1/3)*a*b**2*v**2) - ((16*d**2)/(b*v**2) + (8*(aa))/(a*b**3*v**2) - 8/b**3)/(4*np.sqrt((2**(1/3)*(a*b**2*d**2 - a*v**2 - b*r)**2)/(dd*(bb - cc + ee*(aa)*d**2 + 2 *(aa)**3 + np.sqrt((bb - cc + ee*(aa)*d**2 + 2*(aa)**3)**2 - 4*(aa)**6))**(1/3)) - (2*(aa))/(dd) + (bb - cc + ee*(aa)*d**2 + 2*(aa)**3 + np.sqrt((bb - cc + ee*(aa)*d**2 + 2*(aa)**3)**2 - 4*(aa)**6))**(1/3)/(3*2**(1/3)*a*b**2*v**2) + 1/b**2)) + 2/b**2) - 1/(2*b))
# Out:
# 2 1
# /home/david/.local/lib/python3.7/site-packages/ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in sqrt
#   if sys.path[0] == '':

# %%
wolfram -a*d**2/x**2+a*v**2+br/(1+bx)**2==0, x>0, b>0, r>0, a>0, d>0
# Out:
# nan

# %%
#theo model
def v(alpha =1, beta=1, d=0.95, vb=0):
    plt.figure(1)
    T = np.linspace(0.05, 5, 201)

    e = (alpha*(d**2))/(T)- 2*alpha*d*vb + alpha*T*vb**2 
    t = beta*T**3


    de = (-(alpha*d**2)/(T**2))+ alpha*vb**2
    dt = 3*beta*T**2

    Y = e + t
    dY = de + dt
    
    plt.plot(T, Y, c='k')
    plt.plot(T, dY, c='k', alpha=0.25)

    plt.plot(T, e, c='r')
    plt.plot(T, t, c='g')
    #plt.plot(T, de, c='r', alpha=0.25)
    #plt.plot(T, dt, c='g', alpha=0.25)

    #plt.scatter(T[np.argmin(Y)], Y[np.argmin(Y)], c='g')
    #print(T[np.argmin(Y)], Y[np.argmin(Y)])

    vopt = np.sqrt(np.sqrt((3*beta*d**2)/alpha))
    tf = d/vopt * (1-(0.25*vb**2)/(vopt**2))

    print("vopt=", vopt, "tf=", tf)
    plt.axvline(tf, 0, 1, ls='--', color='c', lw=0.5)
    

    plt.ylim(-5, 25)
    plt.xlim(0, 2.5)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()

interactive_plot = interactive(v, alpha=(1, 20,1), beta=(1, 20,1), d=(0.30, 0.95, 0.3), vb=(-.20, .20, .10))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(IntSlider(value=1, description='alpha', max=20, min=1), IntSlider(value=1, description='…

# %%
#theo model
def compute_tf(alpha =1, beta=1, d=0.95, vb=0):
    vopt = np.sqrt(np.sqrt((3*beta*d**2)/alpha))
    tf = d/vopt * (1-(0.25*vb**2)/(vopt**2))
    return tf
ttf=compute_tf(alpha =6, beta=1, d=0.95, vb=0)
print(ttf)
# Out:
# 1.1590957183315105

# %%
def modelplot(d=.9, Vbelt=0, alpha = 1, beta = 1, ticks=[[],[],[],[]], xylim=[], xyLabels=[], ssize = [1, 1], colors=[] ):
    ax = plt.gca()
    T = np.linspace(0.01, 2.5, 201)
    CM = (alpha*d**2)/T -2*alpha*d*Vbelt + alpha*T*Vbelt**2
    CT = beta*T
    Vopt = np.sqrt(beta/alpha)
    topt = (d/Vopt) * (1 - 0.5*((Vbelt**2)/(Vopt**2)))
    Copt = (alpha*d**2)/topt -2*alpha*d*Vbelt + alpha*topt*Vbelt**2 + beta*topt

    ax.plot(T, CM, label='$\mathregular{C_E}$', color=colors[0][0], lw=ssize[0], alpha=colors[1][0])
    ax.plot(T, CT, label='$\mathregular{C_T}$', color=colors[0][1], lw=ssize[0], alpha=colors[1][1])
    ax.plot(T, CM+CT, label='$\mathregular{C_E + C_T}$', color=colors[0][2], lw=ssize[0], alpha=colors[1][2])
    plt.scatter(topt, Copt, color=colors[0][2], s=ssize[1]**2, alpha=colors[1][2])
    #plt.annotate("min", (topt-0.1, Copt+2), color='k', fontsize=xyLabels[3]-2)

    ax.set_xlabel(xyLabels[0], fontsize = xyLabels[2])
    ax.set_ylabel(xyLabels[1], fontsize = xyLabels[2])
    ax.set_xlim([xylim[0], xylim[1]])
    ax.set_ylim([xylim[2], xylim[3]])
    ax.spines['top'].set_color("none")
    ax.spines['right'].set_color("none")
    ax.spines['bottom'].set_linewidth(2.5)
    ax.spines['left'].set_linewidth(2.5)
    ax.yaxis.set_label_coords(-0.15,0.5)
    ax.tick_params(width=2.5, labelsize = xyLabels[3]) 
    if ticks[0] != []: 
        ax.set_xticks(ticks[0])
        if ticks[2] != []:
            ax.xaxis.set_major_locator(plt.FixedLocator(ticks[0]))
            ax.xaxis.set_major_formatter(plt.FixedFormatter(ticks[2]))
    if ticks[1] != []: 
        ax.set_yticks(ticks[1])
        if ticks[3] != []:
            ax.yaxis.set_major_locator(plt.FixedLocator(ticks[1]))
            ax.yaxis.set_major_formatter(plt.FixedFormatter(ticks[3]))
    #ax.legend(fontsize=xyLabels[3]-2)
    return ax

def tfplot(d=.9, Vbelt=0, alpha = 1, beta = 1, ticks=[[],[],[],[]], xylim=[], xyLabels=[], ssize = [1, 1], colors=[] ):
    ax = plt.gca()
    T = np.linspace(0.01, 2.5, 201)
    CM = (alpha*d**2)/T -2*alpha*d*Vbelt + alpha*T*Vbelt**2
    CT = beta*T
    Vopt = np.sqrt(beta/alpha)
    topt = (d/Vopt) * (1 - 0.5*((Vbelt**2)/(Vopt**2)))
    Copt = (alpha*d**2)/topt -2*alpha*d*Vbelt + alpha*topt*Vbelt**2 + beta*topt

    # ax.plot(T, CM, label='$\mathregular{C_E}$', color=colors[0][0], lw=ssize[0], alpha=colors[1][0])
    # ax.plot(T, CT, label='$\mathregular{C_T}$', color=colors[0][1], lw=ssize[0], alpha=colors[1][1])
    # ax.plot(T, CM+CT, label='$\mathregular{C_E + C_T}$', color=colors[0][2], lw=ssize[0], alpha=colors[1][2])
    # plt.scatter(topt, Copt, color=colors[0][2], s=ssize[1])
    #plt.annotate("min", (topt-0.1, Copt+2), color='k', fontsize=xyLabels[3]-2)

    # ax.set_xlabel(xyLabels[0], fontsize = xyLabels[2])
    # ax.set_ylabel(xyLabels[1], fontsize = xyLabels[2])
    # ax.set_xlim([xylim[0], xylim[1]])
    # ax.set_ylim([xylim[2], xylim[3]])
    # ax.spines['top'].set_color("none")
    # ax.spines['right'].set_color("none")
    # ax.spines['bottom'].set_linewidth(2.5)
    # ax.spines['left'].set_linewidth(2.5)
    # ax.yaxis.set_label_coords(-0.15,0.5)
    # ax.tick_params(width=2.5, labelsize = xyLabels[3]) 
    # if ticks[0] != []: 
    #     ax.set_xticks(ticks[0])
    #     if ticks[2] != []:
    #         ax.xaxis.set_major_locator(plt.FixedLocator(ticks[0]))
    #         ax.xaxis.set_major_formatter(plt.FixedFormatter(ticks[2]))
    # if ticks[1] != []: 
    #     ax.set_yticks(ticks[1])
    #     if ticks[3] != []:
    #         ax.yaxis.set_major_locator(plt.FixedLocator(ticks[1]))
    #         ax.yaxis.set_major_formatter(plt.FixedFormatter(ticks[3]))
    #ax.legend(fontsize=xyLabels[3]-2)
    return topt, Copt

# %%
for d in [0.3, 0.6, 0.9]: modelplot(d=d, Vbelt=0, alpha=5, beta=3.5, ticks = [[],[],[],[]], xylim=[0.0, 2, 0.0, 25], xyLabels = ['Duration (s)', 'Cost (a.u.)', 12, 12], ssize=[2, 5], colors = [['r', 'g', 'b'], [d, 1, d]])
plt.plot(tfplot(d=np.linspace(0, 2, 201), Vbelt=0, alpha=5, beta=3.5))
# Out:
# /home/david/.local/lib/python3.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide

# %%
plt.plot(tfplot(d=np.linspace(0, 2, 201), Vbelt=0, alpha=5, beta=3.5))
# Out:
# /home/david/.local/lib/python3.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide

# %%
plt.plot(np.linspace(-.20, .2, 5), compute_tf(alpha =6, beta=3.5, d=0.9, vb=np.linspace(-.20, .2, 5)))

# %%
#theo model
def v(alpha =1, beta=1, d=0.95, vb=0):
    fig = plt.figure(constrained_layout = False, figsize=(5, 5))
    T = np.linspace(0.05, 5, 201)

    e = (alpha*(d**2))/(T)- 2*alpha*d*vb + alpha*T*vb**2 
    t = beta*T**3


    de = (-(alpha*d**2)/(T**2))+ alpha*vb**2
    dt = 3*beta*T**2

    Y = e + t
    dY = de + dt
    
    plt.plot(T, Y, c='k', label="total cost")
    #plt.plot(T, dY, c='k', alpha=0.25)

    plt.plot(T, e, c='r', label="effort cost")
    plt.plot(T, t, c='g', label="time cost")
    #plt.plot(T, de, c='r', alpha=0.25)
    #plt.plot(T, dt, c='g', alpha=0.25)

    plt.scatter(T[np.argmin(Y)], Y[np.argmin(Y)], c='k')
    #print(T[np.argmin(Y)], Y[np.argmin(Y)])

    plt.ylim(0, 25)
    plt.xlim(0, 2.5)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.legend()
    plt.show()
v(alpha =8, beta=1, d=0.95, vb=0)

# %%
import sympy as sym

# %%
t = sym.Symbol('t',positive=True,real=True)
a = sym.Symbol('a',positive=True,real=True)
b = sym.Symbol('b',positive=True,real=True)
d = sym.Symbol('d',positive=True,real=True)
R = sym.Symbol('R',positive=True,real=True)
v = sym.Symbol('v',positive=True,real=True)

# %%
from sympy import init_printing, S, oo
#soln = sym.solveset(eq, t, simplify=True,real=True,positive=True,)
soln = sym.solveset((-a*d**2)/t**2 
+a*v**2 
+ (b*R)/((1+b*t)**2), t, domain=S.Reals)
init_printing()

print(soln)
# Out:
# Complement(Intersection(FiniteSet(Piecewise((-sqrt(-2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**(1/3) + b**(-2) - 2*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2))/2 - sqrt((-4*d**2/(b*v**2) + 4*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)/sqrt(-2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**(1/3) + b**(-2) - 2*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2)) + 2*(-(-3/(2*b**2) + (R*b - a*b**2
# ...

# %%
Complement(Intersection(FiniteSet(Piecewise((-sqrt(-2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**(1/3) + b**(-2) - 2*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2))/2 - sqrt((-4*d**2/(b*v**2) + 4*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)/sqrt(-2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**(1/3) + b**(-2) - 2*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2)) + 2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**(1/3) + 2/b**2 - 4*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2))/2 - 1/(2*b), Eq(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2), 0)), (-sqrt(-2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))/(3*((-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/216 - (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/6 + (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/16 + sqrt((-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))**3/27 + (-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**2/4))**(1/3)) + 2*((-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/216 - (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/6 + (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/16 + sqrt((-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))**3/27 + (-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**2/4))**(1/3) + b**(-2) - 2*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2))/2 - sqrt((-4*d**2/(b*v**2) + 4*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)/sqrt(-2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))/(3*((-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/216 - (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/6 + (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/16 + sqrt((-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))**3/27 + (-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**2/4))**(1/3)) + 2*((-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/216 - (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/6 + (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/16 + sqrt((-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))**3/27 + (-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**2/4))**(1/3) + b**(-2) - 2*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2)) + 2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))/(3*((-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/216 - (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/6 + (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/16 + sqrt((-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))**3/27 + (-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**2/4))**(1/3)) - 2*((-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/216 - (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/6 + (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/16 + sqrt((-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))**3/27 + (-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**2/4))**(1/3) + 2/b**2 - 4*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2))/2 - 1/(2*b), True)), Piecewise((-sqrt(-2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**(1/3) + b**(-2) - 2*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2))/2 + sqrt((-4*d**2/(b*v**2) + 4*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)/sqrt(-2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**(1/3) + b**(-2) - 2*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2)) + 2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**(1/3) + 2/b**2 - 4*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2))/2 - 1/(2*b), Eq(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2), 0)), (-sqrt(-2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))/(3*((-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/216 - (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/6 + (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/16 + sqrt((-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))**3/27 + (-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**2/4))**(1/3)) + 2*((-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/216 - (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/6 + (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/16 + sqrt((-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))**3/27 + (-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**2/4))**(1/3) + b**(-2) - 2*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2))/2 + sqrt((-4*d**2/(b*v**2) + 4*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)/sqrt(-2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))/(3*((-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/216 - (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/6 + (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/16 + sqrt((-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))**3/27 + (-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**2/4))**(1/3)) + 2*((-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/216 - (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/6 + (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/16 + sqrt((-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))**3/27 + (-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**2/4))**(1/3) + b**(-2) - 2*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2)) + 2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))/(3*((-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/216 - (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/6 + (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/16 + sqrt((-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))**3/27 + (-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**2/4))**(1/3)) - 2*((-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/216 - (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/6 + (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/16 + sqrt((-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))**3/27 + (-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**2/4))**(1/3) + 2/b**2 - 4*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2))/2 - 1/(2*b), True)), Piecewise((sqrt(-2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**(1/3) + b**(-2) - 2*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2))/2 - sqrt(-(-4*d**2/(b*v**2) + 4*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)/sqrt(-2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**(1/3) + b**(-2) - 2*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2)) + 2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**(1/3) + 2/b**2 - 4*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2))/2 - 1/(2*b), Eq(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2), 0)), (sqrt(-2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))/(3*((-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/216 - (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/6 + (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/16 + sqrt((-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))**3/27 + (-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**2/4))**(1/3)) + 2*((-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/216 - (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/6 + (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/16 + sqrt((-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))**3/27 + (-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**2/4))**(1/3) + b**(-2) - 2*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2))/2 - sqrt(-(-4*d**2/(b*v**2) + 4*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)/sqrt(-2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))/(3*((-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/216 - (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/6 + (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/16 + sqrt((-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))**3/27 + (-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**2/4))**(1/3)) + 2*((-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/216 - (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/6 + (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/16 + sqrt((-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))**3/27 + (-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**2/4))**(1/3) + b**(-2) - 2*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2)) + 2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))/(3*((-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/216 - (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/6 + (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/16 + sqrt((-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))**3/27 + (-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**2/4))**(1/3)) - 2*((-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/216 - (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/6 + (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/16 + sqrt((-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))**3/27 + (-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**2/4))**(1/3) + 2/b**2 - 4*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2))/2 - 1/(2*b), True)), Piecewise((sqrt(-2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**(1/3) + b**(-2) - 2*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2))/2 + sqrt(-(-4*d**2/(b*v**2) + 4*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)/sqrt(-2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**(1/3) + b**(-2) - 2*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2)) + 2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**(1/3) + 2/b**2 - 4*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2))/2 - 1/(2*b), Eq(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2), 0)), (sqrt(-2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))/(3*((-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/216 - (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/6 + (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/16 + sqrt((-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))**3/27 + (-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**2/4))**(1/3)) + 2*((-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/216 - (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/6 + (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/16 + sqrt((-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))**3/27 + (-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**2/4))**(1/3) + b**(-2) - 2*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2))/2 + sqrt(-(-4*d**2/(b*v**2) + 4*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)/sqrt(-2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))/(3*((-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/216 - (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/6 + (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/16 + sqrt((-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))**3/27 + (-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**2/4))**(1/3)) + 2*((-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/216 - (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/6 + (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/16 + sqrt((-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))**3/27 + (-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**2/4))**(1/3) + b**(-2) - 2*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2)) + 2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))/(3*((-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/216 - (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/6 + (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/16 + sqrt((-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))**3/27 + (-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**2/4))**(1/3)) - 2*((-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/216 - (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/6 + (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/16 + sqrt((-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**2/12 + 2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b + d**2/(b**2*v**2))**3/27 + (-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**2/4))**(1/3) + 2/b**2 - 4*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2))/2 - 1/(2*b), True))), Reals), FiniteSet(0, -1/b))

# %%
print(soln)
# Out:
# Complement(FiniteSet(Piecewise((-sqrt(-2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**(1/3) + b**(-2) - 2*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2))/2 - sqrt((-4*d**2/(b*v**2) + 4*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)/sqrt(-2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))**3/108 + (-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**2)/(a*b**2*v**2))*(-2*(-d**2/(2*b*v**2) + 2*(3/(64*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(16*a*b**2*v**2))/b)/b - d**2/(b**2*v**2))/3 - (-2*d**2/(b*v**2) + 2*(1/(2*b**2) - (R*b - a*b**2*d**2 + a*v**2)/(2*a*b**2*v**2))/b)**2/8)**(1/3) + b**(-2) - 2*(R*b - a*b**2*d**2 + a*v**2)/(3*a*b**2*v**2)) + 2*(-(-3/(2*b**2) + (R*b - a*b**2*d**2 + a*v**
# ...

# %%
{x -> ConditionalExpression[Root[(-a)*d^2 - 2*a*b*d^2*#1 + ((-a)*b^2*d^2 + b*r + a*v^2)*#1^2 + 2*a*b*v^2*#1^3 + a*b^2*v^2*#1^4 & , 2], 
(d > 0 && r > 0 && a > 0 && Inequality[-1, Less, v, Less, 0] && Inequality[0, Less, b, Less, -(v/d)]) || 
(d > 0 && r > 0 && a > 0 && Inequality[0, Less, v, Less, 1] && Inequality[0, Less, b, Less, v/d]) || 
(d > 0 && r > 0 && b > -(v/d) && Inequality[-1, Less, v, Less, 0] && Inequality[0, Less, a, Less, Root[-(b^3*r^3) + (3*b^4*d^2*r^2 - 3*b^2*r^2*v^2)*#1 + (-3*b^5*d^4*r - 21*b^3*d^2*r*v^2 - 3*b*r*v^4)*#1^2 + (b^6*d^6 - 3*b^4*d^4*v^2 + 3*b^2*d^2*v^4 - v^6)*#1^3 & , 1]]) || 
(d > 0 && r > 0 && b > v/d && Inequality[0, Less, a, Less, Root[-(b^3*r^3) + (3*b^4*d^2*r^2 - 3*b^2*r^2*v^2)*#1 + (-3*b^5*d^4*r - 21*b^3*d^2*r*v^2 - 3*b*r*v^4)*#1^2 + (b^6*d^6 - 3*b^4*d^4*v^2 + 3*b^2*d^2*v^4 - v^6)*#1^3 & , 1]] && Inequality[0, Less, v, Less, 1])]}, 


{x -> ConditionalExpression[Root[(-a)*d^2 - 2*a*b*d^2*#1 + ((-a)*b^2*d^2 + b*r + a*v^2)*#1^2 + 2*a*b*v^2*#1^3 + a*b^2*v^2*#1^4 & , 4], 
(d > 0 && r > 0 && a > Root[-(b^3*r^3) + (3*b^4*d^2*r^2 - 3*b^2*r^2*v^2)*#1 + (-3*b^5*d^4*r - 21*b^3*d^2*r*v^2 - 3*b*r*v^4)*#1^2 + (b^6*d^6 - 3*b^4*d^4*v^2 + 3*b^2*d^2*v^4 - v^6)*#1^3 & , 1] && b > v/d && Inequality[0, Less, v, Less, 1]) || 
(d > 0 && r > 0 && b > -(v/d) && a > Root[-(b^3*r^3) + (3*b^4*d^2*r^2 - 3*b^2*r^2*v^2)*#1 + (-3*b^5*d^4*r - 21*b^3*d^2*r*v^2 - 3*b*r*v^4)*#1^2 + (b^6*d^6 - 3*b^4*d^4*v^2 + 3*b^2*d^2*v^4 - v^6)*#1^3 & , 1] && Inequality[-1, Less, v, Less, 0])]}}

# %%
{x -> ConditionalExpression[Root[(-a)*d^2 - 2*a*b*d^2*#1 + ((-a)*b^2*d^2 + b*r + a*v^2)*#1^2 + 2*a*b*v^2*#1^3 + a*b^2*v^2*#1^4 & , 2], 

(d > 0 && r > 0 && a > 0      && Inequality[-1, Less, v, Less, 0] && Inequality[0, Less, b, Less, -(v/d)]) || 
(d > 0 && r > 0 && a > 0      && Inequality[0, Less, v, Less, 1] && Inequality[0, Less, b, Less, v/d]) || 
(d > 0 && r > 0 && b > -(v/d) && Inequality[-1, Less, v, Less, 0] && Inequality[0, Less, a, Less, Root[-(b^3*r^3) + (3*b^4*d^2*r^2 - 3*b^2*r^2*v^2)*#1 + (-3*b^5*d^4*r - 21*b^3*d^2*r*v^2 - 3*b*r*v^4)*#1^2 + (b^6*d^6 - 3*b^4*d^4*v^2 + 3*b^2*d^2*v^4 - v^6)*#1^3 & , 1]]) || 
(d > 0 && r > 0 && b > v/d    && Inequality[0, Less, a, Less, Root[-(b^3*r^3) + (3*b^4*d^2*r^2 - 3*b^2*r^2*v^2)*#1 + (-3*b^5*d^4*r - 21*b^3*d^2*r*v^2 - 3*b*r*v^4)*#1^2 + (b^6*d^6 - 3*b^4*d^4*v^2 + 3*b^2*d^2*v^4 - v^6)*#1^3 & , 1]] && Inequality[0, Less, v, Less, 1])]}

# %%
{{x -> ConditionalExpression[Root[(-a)*d^2 - 2*a*b*d^2*#1 + ((-a)*b^2*d^2 + b*r + a*v^2)*#1^2 + 2*a*b*v^2*#1^3 + a*b^2*v^2*#1^4 & , 2], 
(Inequality[0, Less, a, Less, Root[-(b^3*r^3) + (3*b^4*d^2*r^2 - 3*b^2*r^2*v^2)*#1 + (-3*b^5*d^4*r - 21*b^3*d^2*r*v^2 - 3*b*r*v^4)*#1^2 + (b^6*d^6 - 3*b^4*d^4*v^2 + 3*b^2*d^2*v^4 - v^6)*#1^3 & , 1]] && b > v/d && d > 0 && r > 0 && v > 0) || 
(Inequality[0, Less, b, Less, v/d] && a > 0 && d > 0 && r > 0 && v > 0)]}, 

{x -> ConditionalExpression[ Root[(-a)*d^2 - 2*a*b*d^2*#1 + ((-a)*b^2*d^2 + b*r + a*v^2)*#1^2 + 2*a*b*v^2*#1^3 + a*b^2*v^2*#1^4 & , 4], 
a > Root[-(b^3*r^3) + (3*b^4*d^2*r^2 - 3*b^2*r^2*v^2)*#1 + (-3*b^5*d^4*r - 21*b^3*d^2*r*v^2 - 3*b*r*v^4)*#1^2 + (b^6*d^6 - 3*b^4*d^4*v^2 + 3*b^2*d^2*v^4 - v^6)*#1^3 & , 1] && b > v/d && d > 0 && r > 0 && v > 0]}}

# %%
# optimal time computation

from ipywidgets import interactive

def v(d=.9, Vbelt=0, alpha = 1, beta = 1, R=1):

    fig = plt.figure(constrained_layout = False, figsize=(7.5, 4.5))
    plt.figure(1)
    T = np.linspace(0.01, 2.5, 201)

    CM = (alpha*d**2)/T -2*alpha*d*Vbelt + alpha*T*Vbelt**2
    dCM = (-alpha*d**2)/T**2 + alpha*Vbelt**2
    
    CT = beta*T
    dCT = beta
    dCTplot = np.full((len(T),1), beta)

    
    plt.plot(T, CM, label='mvt cost', color='r')
    plt.plot(T, dCM, label='dmvt cost', color='r', alpha = 0.25)

    plt.plot(T, CT, label='time cost', color='g')
    plt.plot(T, dCTplot, label='dtime cost', color='g', alpha = 0.25)

    plt.plot(T, CM+CT, label='total cost', color='k')
    plt.plot(T, dCM+dCT, label='dtotal cost', color='k', alpha = 0.25)

    # CT2 = R - (R/(1+beta*T))
    # plt.plot(T, CT2, label='time cost', color='g')

    Vopt = np.sqrt(beta/alpha)
    #tfexact = np.sqrt((alpha*d**2)/(alpha*Vbelt**2+beta))
    tfapprox = (d/Vopt) * (1 - 0.5*((Vbelt**2)/(Vopt**2)))
    #print("tfexact=", tfexact)
    print("tfapprox=", tfapprox, "Vopt=", Vopt)
    plt.axvline(tfapprox, 0, 1, ls='--', color='c', lw=0.5)

    plt.legend()
    plt.ylim(0, 25)
    plt.xlim(0, 2.5)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()
    


interactive_plot = interactive(v, d=(.30, .9, .3), Vbelt=(-0.20, .20, .10), alpha=(1, 10, 1), beta=(1, 10, 1), R=(1, 10, 1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=0.9, description='d', max=0.9, min=0.3, step=0.3), FloatSlider(value=0…

# %%
from ipywidgets import interactive

def v(d=.9, Vbelt=0, alpha = 1, beta = 1, R=1):

    fig = plt.figure(constrained_layout = False, figsize=(5, 5))
    plt.figure(1)
    T = np.linspace(0.01, 2.5, 201)

    CM = (alpha*d**2)/T -2*alpha*d*Vbelt + alpha*T*Vbelt**2
    dCM = (-alpha*d**2)/T**2 + alpha*Vbelt**2
    
    CT = beta*T
    dCT = beta
    dCTplot = np.full((len(T),1), beta)

    
    plt.plot(T, CM, label='mvt cost', color='r')
    plt.plot(T, dCM, label='dmvt cost', color='r', alpha = 0.25)

    plt.plot(T, CT, label='time cost', color='g')
    plt.plot(T, dCTplot, label='dtime cost', color='g', alpha = 0.25)

    plt.plot(T, CM+CT, label='total cost', color='k')
    plt.plot(T, dCM+dCT, label='dtotal cost', color='k', alpha = 0.25)

    # CT2 = R - (R/(1+beta*T))
    # plt.plot(T, CT2, label='time cost', color='g')

    Vopt = np.sqrt(beta/alpha)
    #tfexact = np.sqrt((alpha*d**2)/(alpha*Vbelt**2+beta))
    tfapprox = (d/Vopt) * (1 - 0.5*((Vbelt**2)/(Vopt**2)))
    #print("tfexact=", tfexact)
    print("tfapprox=", tfapprox, "Vopt=", Vopt)
    plt.axvline(tfapprox, 0, 1, ls='--', color='c', lw=0.5)

    plt.legend()
    plt.ylim(0, 25)
    plt.xlim(0, 2.5)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()
    
v(d=(.9), Vbelt=(0), alpha=(5), beta=(5), R=(0))
# Out:
# tfapprox= 0.9 Vopt= 1.0
