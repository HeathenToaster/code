# %%
import matplotlib.pyplot as plt
import numpy as np
from ipywidgets import interact

# %%
def reward(alpha, gamma, mvtT):
    return alpha/(1+gamma * mvtT)
def effort(a, mass, mvtT, b, dist, gamma, i, j):
    return (a*mass*mvtT + ((b*mass*dist**i) / (mvtT**(j-1)))) / (1+(gamma*mvtT))
def effortwalk(a, mass, mvtT, b, dist, gamma):
    return (a*mass*mvtT + ((b*mass*dist**2) / (mvtT))) / (1+(gamma*mvtT))

# %%
T = np.linspace(0, 1, 100)

# %% [markdown]
# $$
#   Reward = \frac{\alpha} {1+\gamma*T}
# $$
# $$
#   Effort = -\frac{amT + \frac{bmd²}{T}}{1+\gamma*T}
# $$

# %%
fig = plt.figure(constrained_layout = False, figsize=(5, 5))
plt.plot(T, reward(0.5, 1, T), color = 'c')
plt.plot(T, -effort(a=15, mass=2, mvtT=T, b=77, dist=0.1, gamma=1, i=1.1, j=2.7)/1000, color = 'r')
plt.plot(T, (reward(alpha=0.5, gamma=1, mvtT=T) - effort(a=15, mass=2, mvtT=T, b=77, dist=.1, gamma=1, i=1.1, j=2.7)/1000), color='k')
plt.xlim(0.1, 1)
plt.ylim(-1,1)
plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
# Out:
# /home/david/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.
# /home/david/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.

# %%
fig = plt.figure(constrained_layout = False, figsize=(5, 5))
plt.plot(T, 0.5 - reward(0.5, 1, T), color = 'c')
plt.plot(T, effort(a=15, mass=2, mvtT=T, b=77, dist=0.1, gamma=1, i=1.1, j=2.7)/1000, color = 'r')
plt.plot(T, (.5-reward(alpha=0.5, gamma=1, mvtT=T) + effort(a=15, mass=2, mvtT=T, b=77, dist=.1, gamma=1, i=1.1, j=2.7)/1000), color='k')
plt.xlim(0.0, 1)
plt.ylim(0,1)
plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
# Out:
# /home/david/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.
# /home/david/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.

# %%
#increased reward
fig = plt.figure(constrained_layout = False, figsize=(5, 5))
Y1 = reward(alpha=1, gamma=1, mvtT=T) - effort(a=15, mass=2, mvtT=T, b=77, dist=.1, gamma=1, i=1.1, j=2.7)/1000
Y2 = reward(alpha=0.5, gamma=1, mvtT=T) - effort(a=15, mass=2, mvtT=T, b=77, dist=.1, gamma=1, i=1.1, j=2.7)/1000
plt.plot(T, Y1, color='g')
plt.plot(T, Y2, color='k')

plt.scatter(T[np.argmax(Y1)], Y1[np.argmax(Y1)], c='g')
plt.scatter(T[np.argmax(Y2)], Y2[np.argmax(Y2)], c='k')
plt.xlim(0.1, 1)
plt.ylim(-1,1)
plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
# Out:
# /home/david/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.

# %%
#increased mass
fig = plt.figure(constrained_layout = False, figsize=(5, 5))
Y1 = reward(alpha=0.5, gamma=1, mvtT=T) - effort(a=15, mass=2, mvtT=T, b=77, dist=.1, gamma=1, i=1.1, j=2.7)/1000
Y2 = reward(alpha=0.5, gamma=1, mvtT=T) - effort(a=15, mass=3, mvtT=T, b=77, dist=.1, gamma=1, i=1.1, j=2.7)/1000
plt.plot(T, Y1, color='g')
plt.plot(T, Y2, color='k')

plt.scatter(T[np.argmax(Y1)], Y1[np.argmax(Y1)], c='g')
plt.scatter(T[np.argmax(Y2)], Y2[np.argmax(Y2)], c='k')
plt.xlim(0.1, 1)
plt.ylim(-1,1)
plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
# Out:
# /home/david/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.

# %%
#increased time sensitivity
fig = plt.figure(constrained_layout = False, figsize=(5, 5))

Y1 = reward(alpha=0.5, gamma=1, mvtT=T) - effort(a=15, mass=2, mvtT=T, b=77, dist=.1, gamma=1, i=1.1, j=2.7)/1000
Y2 = reward(alpha=0.5, gamma=2, mvtT=T) - effort(a=15, mass=2, mvtT=T, b=77, dist=.1, gamma=2, i=1.1, j=2.7)/1000
plt.plot(T, Y1, color='g')
plt.plot(T, Y2, color='k')

plt.scatter(T[np.argmax(Y1)], Y1[np.argmax(Y1)], c='g')
plt.scatter(T[np.argmax(Y2)], Y2[np.argmax(Y2)], c='k')
plt.xlim(0.1, 1)
plt.ylim(-1,1)
plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
# Out:
# /home/david/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.

# %%
#increased reward
fig = plt.figure(constrained_layout = False, figsize=(5, 5))

def alphaslider(a): return a

alpha = 0.5
gamma = 1
mvtT  = T

a = 15
b = 77
mass = 0.4
dist = .1

Y1 = reward(alpha=alpha, gamma=gamma, mvtT=mvtT) - effortwalk(a=a, mass=mass, mvtT=mvtT, b=b, dist=dist, gamma=gamma)/1000
Y2 = reward(alpha=0.5, gamma=1, mvtT=T) - effortwalk(a=15, mass=2, mvtT=T, b=77, dist=.1, gamma=1)/1000
plt.plot(T, Y1, color='g')
plt.plot(T, Y2, color='k')

plt.scatter(T[np.argmax(Y1)], Y1[np.argmax(Y1)], c='g')
plt.scatter(T[np.argmax(Y2)], Y2[np.argmax(Y2)], c='k')
plt.xlim(0, 1)
plt.ylim(-1,1)
plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
# Out:
# /home/david/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in true_divide

# %%
# %matplotlib inline
from ipywidgets import interactive


Y2 = reward(alpha=0.5, gamma=1, mvtT=T) - effortwalk(a=15, mass=2, mvtT=T, b=77, dist=.1, gamma=1)/1000

def f(a, b, alpha, gamma, mass, dist):
    plt.figure(2)
    T = np.linspace(0, 1, 100)
    Y = alpha/(1+gamma*T) - (a*mass*T + ((b*mass*dist**2) / (T))) / (1+(gamma*T))/1000
    plt.plot(T, Y)
    plt.scatter(T[np.argmax(Y)], Y[np.argmax(Y)], c='k')
    plt.ylim(-1, 1)
    plt.xlim(0, 1)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()

interactive_plot = interactive(f, a=(15), b=(77), alpha=(0, 5.0), gamma=(0, 5, 0.5), mass=(0, 1.0), dist=(0, 2, 0.1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# /home/david/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in true_divide
# interactive(children=(IntSlider(value=15, description='a', max=45, min=-15), IntSlider(value=77, description='…

# %%
#Y2 = reward(alpha=0.5, gamma=1, mvtT=T) - effortwalk(a=15, mass=2, mvtT=T, b=77, dist=.1, gamma=1)/1000
from ipywidgets import interactive

def v(Vmoy, t_0, t_1, mu, sigma, y):
    plt.figure(1)
    T = np.linspace(0.01, 2.5, 500)
    Y = ((Vmoy * (t_1 - t_0)) / (sigma * np.sqrt(2*np.pi) * (T - t_0))) * np.exp(-((np.log((T-t_0)/(t_1-t_0))-mu)**2 ) / (2*sigma**2))
    dY = ((Vmoy * (t_1 - t_0)) * (np.exp(-(((np.log((T-t_0)/(t_1-t_0))-mu)**2 )* 1/(2*sigma**2)))) * (np.log((T-t_0)/(t_1-t_0)) + sigma**2 - mu)) / ((sigma**3) * np.sqrt(2*np.pi) * (T-t_0)**2)
    tVmax = t_0 + np.exp(mu - sigma ** 2) * (t_1-t_0)
    Ymax = ((Vmoy * (t_1 - t_0)) / (sigma * np.sqrt(2*np.pi) * (tVmax - t_0))) * np.exp(-(((np.log((tVmax-t_0)/(t_1-t_0))-mu)**2 )* 1/(2*sigma**2)))
    #print(Ymax)
    plt.plot(T, Y)
    plt.plot(T[Y>15], Y[Y>15], lw = 2)
    #print(T[Y>15], Y[Y>15])

    plt.plot(T, dY, lw=0.5)
    plt.plot((tVmax, tVmax), (-10, 150), color='k', lw=0.5)


    #print((t_1-t_0)/(y*sigma * np.sqrt(2*np.pi)))
    plt.scatter((t_1-t_0)/(y*sigma * np.sqrt(2*np.pi)), 1)

    plt.ylim(0, 120)
    plt.xlim(0, 2.5)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()

interactive_plot = interactive(v, Vmoy=(0, 120, 1), t_0=(0.0), t_1=(0,2.0), mu=(-2,0,0.1), sigma=(0.05, 1, 0.05), y=(0, 10, 1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(IntSlider(value=60, description='Vmoy', max=120), FloatSlider(value=0.0, description='t_…

# %%
#Y2 = reward(alpha=0.5, gamma=1, mvtT=T) - effortwalk(a=15, mass=2, mvtT=T, b=77, dist=.1, gamma=1)/1000
from ipywidgets import interactive

def v(Vmoy, t_0, t_1, mu, sigma, y):
    plt.figure(1)
    T = np.linspace(0.01, 2.5, 500)
    Y = ((Vmoy * (t_1 - t_0)) / (sigma * np.sqrt(2*np.pi) * (T - t_0))) * np.exp(-((np.log((T-t_0)/(t_1-t_0))-mu)**2 ) / (2*sigma**2))
    dY = ((Vmoy * (t_1 - t_0)) * (np.exp(-(((np.log((T-t_0)/(t_1-t_0))-mu)**2 )* 1/(2*sigma**2)))) * (np.log((T-t_0)/(t_1-t_0)) + sigma**2 - mu)) / ((sigma**3) * np.sqrt(2*np.pi) * (T-t_0)**2)
    tVmax = t_0 + np.exp(mu - sigma ** 2) * (t_1-t_0)
    Ymax = ((Vmoy * (t_1 - t_0)) / (sigma * np.sqrt(2*np.pi) * (tVmax - t_0))) * np.exp(-(((np.log((tVmax-t_0)/(t_1-t_0))-mu)**2 )* 1/(2*sigma**2)))
    print(Ymax)
    plt.plot(T, Y)
    plt.plot(T[Y>15], Y[Y>15], lw = 2)
    #print(T[Y>15], Y[Y>15])
    plt.scatter(t_0 + y/(sigma * np.sqrt(2*np.pi)), 0.1)
    print(t_0 + y/(sigma * np.sqrt(2*np.pi)))

    plt.plot(T, dY, lw=0.5)
    plt.plot((tVmax, tVmax), (-10, 150), color='k', lw=0.5)


    plt.ylim(0, 120)
    plt.xlim(0, 2.5)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()

interactive_plot = interactive(v, Vmoy=(0, 120, 1), t_0=(0.0), t_1=(0,2.0), mu=(-2,0,0.5), sigma=(0.05, 1, 0.05), y=(0, 10, 1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(IntSlider(value=60, description='Vmoy', max=120), FloatSlider(value=0.0, description='t_…

# %%
# The Coordination of Arm Movements: An Experimentally Confirmed Mathematical Model
# FLASH & HOGAN, 1985

from ipywidgets import interactive

def vtest2(x_0 = 0, x_f= 95, tf=1.5):
    plt.figure(1)
    T = np.linspace(0, tf, 500)

    Y = x_0 + (x_0 - x_f)*((15 * (T/tf) **4)-(6 * (T/tf) **5)-(10 * (T/tf) **3))
    dY = ((x_0-x_f) * (-30*T**2)*(T-tf)**2)/(tf**5)
    ddY = ((-60*T)*(x_0-x_f) * (2*T**2 - 3*T*tf + tf**2))/(tf**5)


    plt.plot(T, Y)
    plt.plot(T, dY)
    plt.plot(T, ddY/10)

    plt.scatter(tf/2, (-15*(x_0-x_f))/(8*tf))

    plt.ylim(-50, 150)
    plt.xlim(0, 5)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()

interactive_plot = interactive(vtest2, x_0=(0, 120, 1), x_f=(0, 120, 1), tf=(0, 5.0, .1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(IntSlider(value=0, description='x_0', max=120), IntSlider(value=95, description='x_f', m…

# %%
# Analytical model of m–S curve using generalized skewed-parabola
# Naoshi Miyashita a , Tetsuji Kawazura a , Kazuyuki Kabe b
# Advanced Materials Laboratory, Research & Development Center, Yokohama Rubber Co., Ltd., 2-1, Oiwake, Hi

def v(vMax=1, n=2, q=0, tf=2):
    plt.figure(1)
    T = np.linspace(0, tf, 201)
    
    tf=2/tf

    Y = vMax*(1 - np.abs(tf*T - 1)**n) * (1 - q * (tf*T - 1))


    #dYY = ((vMax*tf*n *(1-q*(tf*T-1)) * np.abs(tf*T-1)**n)/(tf*T-1)) - vMax* tf * q* (1-np.abs(tf*T-1)**n)
    #dYY = (2*(-q + (n*(-2*T + tf)*(-2*q*T + tf + q*tf) * np.abs(1 - (2*T)/tf)**(-2 + n))/tf**2 + q*np.abs(1 - (2*T)/tf)**n))/tf
    dYY = n*tf*(-1 + T*tf)*(-1 - q + q*T*tf) *np.abs(-1 + T*tf)**(-2 + n) + q *tf* (-1 + np.abs(-1 + T*tf)**n)
    
    plt.plot(T, Y)
    plt.plot(T, dYY)


    plt.ylim(-2, 2)
    plt.xlim(0, 5)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()

interactive_plot = interactive(v, vMax=(0, 2,.1), n=(0, 10, 1), q=(-1, 1, 0.1), tf=(0, 5, .1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=1.0, description='vMax', max=2.0), IntSlider(value=2, description='n',…

# %%
# Analytical model of m–S curve using generalized skewed-parabola
# Naoshi Miyashita a , Tetsuji Kawazura a , Kazuyuki Kabe b
# Advanced Materials Laboratory, Research & Development Center, Yokohama Rubber Co., Ltd., 2-1, Oiwake, Hi
from ipywidgets import interactive

def v(vMax=1, n=2, q=0, tf=2):
    plt.figure(1)
    T = np.linspace(-25, 25, 201)
    
    tf=2/tf

    Y = vMax*(1 - (tf*T - 1)**n) * (1 - q * (tf*T - 1))
    dYY = vMax*tf*n* (tf*T - 1)**(n-1) * (q * (tf*T - 1)-1) + tf*q*((tf*T - 1)**n-1)
    dYY = vMax*tf*n* (tf*T - 1)**(n-1) * (q * (tf*T - 1)-1) + tf*q*((tf*T - 1)**n-1)
    
    plt.plot(T, Y)
    plt.plot(T, dYY)

    plt.ylim(-25, 25)
    plt.xlim(-25, 25)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()

interactive_plot = interactive(v, vMax=(0, 2,.1), n=(0, 10, 1), q=(-1, 1, 0.1), tf=(0, 5, .1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=1.0, description='vMax', max=2.0), IntSlider(value=2, description='n',…

# %%
 
def calc_parabola_vertex(x1, y1, x2, y2, x3, y3):
    denom = (x1-x2) * (x1-x3) * (x2-x3);
    A     = (x3 * (y2-y1) + x2 * (y1-y3) + x1 * (y3-y2)) / denom;
    B     = (x3*x3 * (y1-y2) + x2*x2 * (y3-y1) + x1*x1 * (y2-y3)) / denom;
    C     = (x2 * x3 * (x2-x3) * y1+x3 * x1 * (x3-x1) * y2+x1 * x2 * (x1-x2) * y3) / denom;
    return A,B,C


from ipywidgets import interactive

def v(Vmax, tf):
    plt.figure(1)
    x1,y1=[0,0]
    x2,y2=[tf,0]
    x3,y3=[tf/2,Vmax]

    a,b,c=calc_parabola_vertex(x1, y1, x2, y2, x3, y3)
    x_pos=np.linspace(0,tf,100)
    y_pos=[]

    #Calculate y values 
    for x in range(len(x_pos)):
        x_val=x_pos[x]
        y=(a*(x_val**2))+(b*x_val)+c
        y_pos.append(y)

    print("y=", a, "x**2 + ", b, "x +", c)
    plt.plot(x_pos, y_pos, linestyle='-.', color='black') # parabola line
    plt.scatter(x_pos, y_pos, color='gray') # parabola points
    plt.scatter(x1,y1,color='r',marker="D",s=50) # 1st known xy
    plt.scatter(x2,y2,color='g',marker="D",s=50) # 2nd known xy
    plt.scatter(x3,y3,color='k',marker="D",s=50) # 3rd known xy
    plt.xlim(0, 5)
    plt.ylim(0, 150)
    plt.show() 


interactive_plot = interactive(v, Vmax=(0, 100, 10), tf=(0, 5.0))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(IntSlider(value=50, description='Vmax', step=10), FloatSlider(value=2.5, description='tf…

# %%
 
def calc_parabola_vertex(x1, y1, x2, y2, x3, y3):
    denom = (x1-x2) * (x1-x3) * (x2-x3);
    A     = (x3 * (y2-y1) + x2 * (y1-y3) + x1 * (y3-y2)) / denom;
    B     = (x3*x3 * (y1-y2) + x2*x2 * (y3-y1) + x1*x1 * (y2-y3)) / denom;
    C     = (x2 * x3 * (x2-x3) * y1+x3 * x1 * (x3-x1) * y2+x1 * x2 * (x1-x2) * y3) / denom;
    return A,B,C
tf=1.5
x1,y1=[0,0]
x2,y2=[tf,0]
x3,y3=[tf/2,100]

#Calculate the unknowns of the equation y=ax^2+bx+c
a,b,c=calc_parabola_vertex(x1, y1, x2, y2, x3, y3)

x_pos=np.linspace(-5,5,100)
y_pos=[]

#Calculate y values 
for x in range(len(x_pos)):
    x_val=x_pos[x]
    y=(a*(x_val**2))+(b*x_val)+c
    y_pos.append(y)
print("y=", a, "x**2 + ", b, "x +", c)
plt.plot(x_pos, y_pos, linestyle='-.', color='black') # parabola line
plt.scatter(x_pos, y_pos, color='gray') # parabola points
plt.scatter(x1,y1,color='r',marker="D",s=50) # 1st known xy
plt.scatter(x2,y2,color='g',marker="D",s=50) # 2nd known xy
plt.scatter(x3,y3,color='k',marker="D",s=50) # 3rd known xy
plt.xlim(0, 2)
plt.ylim(0, 150)
plt.show()
# Out:
# y= -177.77777777777777 x**2 +  266.6666666666667 x + 0.0

# %%
# optimal time computation

from ipywidgets import interactive

def v(d=60, Vbelt=0, Vopt=60):


    tf = (d/Vopt) * (1 - 0.5*((Vbelt**2)/(Vopt**2)))
    print(tf)

    plt.figure(1)
    T = np.linspace(-1000, 1000, 2001)
    
    tf=2/tf

    dY = ((-d**2)/(T**2)) + Vbelt**2
    Y = ((d**2)/T) -2* Vbelt*d + T*Vbelt**2
    
    plt.plot(T, Y, label='mvt cost')
    plt.plot(T, dY)
    plt.legend()
    plt.ylim(-500, 500)
    plt.xlim(-0, 150)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()
    


interactive_plot = interactive(v, d=(0, 100, 1), Vbelt=(-20, 20, 1), Vopt=(30, 100, 1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(IntSlider(value=60, description='d'), IntSlider(value=0, description='Vbelt', max=20, mi…

# %%
# optimal time computation

from ipywidgets import interactive

def v(d=60, Vbelt=0, Vopt=60):


    tf = (d/Vopt) * (1 - 0.5*((Vbelt**2)/(Vopt**2)))
    print(tf)

    plt.figure(1)
    T = np.linspace(-1000, 1000, 2001)
    
    tf=2/tf

    
    Y = ((d**2)/T) -2* Vbelt*d + T*Vbelt**2
    dY = ((-d**2)/(T**2)) + Vbelt**2

    
    plt.plot(T, Y, label='mvt cost')
    plt.plot(T, dY)
    plt.legend()
    plt.ylim(-500, 500)
    plt.xlim(-0, 150)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()
    


interactive_plot = interactive(v, d=(0, 100, 1), Vbelt=(-20, 20, 1), Vopt=(30, 100, 1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(IntSlider(value=60, description='d'), IntSlider(value=0, description='Vbelt', max=20, mi…

# %%
from ipywidgets import interactive

def v(R=1, B=2):
    plt.figure(1)
    T = np.linspace(0, 25, 201)


    Y = R - (R/(1+B*T))
    dYY = (B*R)/((1+B*T)**2)
    
    plt.plot(T, Y)
    plt.plot(T, dYY)

    plt.ylim(0, 25)
    plt.xlim(0, 25)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.axhline(y=R, xmin=0, xmax = 25, ls='--', color='k', lw=0.5)
    plt.show()

interactive_plot = interactive(v, R=(0, 20,.1), B=(0, 10, .1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=1.0, description='R', max=20.0), FloatSlider(value=2.0, description='B…

# %%
# optimal time computation

from ipywidgets import interactive

def v(d=.9, Vbelt=0, alpha = 1, beta = 1):


    # tf = (d/Vopt) * (1 - 0.5*((Vbelt**2)/(Vopt**2)))
    # print(tf)
    fig = plt.figure(constrained_layout = False, figsize=(7.5, 4.5))
    plt.figure(1)
    T = np.linspace(0.01, 2.5, 201)

    mvt = (alpha*d**2)/T -2*alpha*d*Vbelt + alpha*T*Vbelt**2
    time = beta*T**3
    
    dmvt = (-alpha*d**2)/T**2 + alpha*Vbelt**2
    dtime = 3*beta*T**2

    
    plt.plot(T, mvt, label='mvt cost', color='r')
    plt.plot(T, dmvt, label='dmvt cost', color='r', alpha = 0.25)

    plt.plot(T, time, label='time cost', color='g')
    plt.plot(T, dtime, label='dtime cost', color='g', alpha = 0.25)

    plt.plot(T, mvt + time, label='total cost', color='k')
    plt.plot(T, dmvt + dtime, label='dtotal cost', color='k', alpha = 0.25)

    # tf = np.sqrt((-alpha*Vbelt**2 + np.sqrt(alpha**2 * Vbelt**4 + 12*alpha*beta*d**2))/(6*beta))
    # print("tf", tf)
    # plt.axvline(tf, 0, 1, ls='--', color='k', lw=0.5)


    Vopt = np.sqrt(np.sqrt((3*beta*d**2)/alpha))
    print("Vopt", Vopt)


    tf3 = d/Vopt*(1-0.25*Vbelt**2/Vopt**2)
    print("approxtf", tf3)
    plt.axvline(tf3, 0, 1, ls='--', color='c', lw=0.5)

    plt.legend()
    plt.ylim(0, 25)
    plt.xlim(0, 2.5)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()
    


interactive_plot = interactive(v, d=(.30, .9, .3), Vbelt=(-0.20, .20, .10), alpha=(1, 10, 1), beta=(1, 10, 1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=0.9, description='d', max=0.9, min=0.3, step=0.3), FloatSlider(value=0…

# %%
# optimal time computation

from ipywidgets import interactive

def v(d=.9, Vbelt=0, alpha = 1, beta = 1, R=1):


    # tf = (d/Vopt) * (1 - 0.5*((Vbelt**2)/(Vopt**2)))
    # print(tf)
    fig = plt.figure(constrained_layout = False, figsize=(7.5, 4.5))
    plt.figure(1)
    T = np.linspace(0.01, 2.5, 201)

    mvt = (alpha*d**2)/T -2*alpha*d*Vbelt + alpha*T*Vbelt**2
    time3 = beta*T**3
    time1 = beta*T
    
    dmvt = (-alpha*d**2)/T**2 + alpha*Vbelt**2
    dtime3 = 3*beta*T**2
    dtime1 = beta*T

    Y = R - (R/(1+beta*T))
    dYY = (beta*R)/((1+beta*T)**2)
    
    plt.plot(T, Y)
    #plt.plot(T, dYY)
    
    plt.plot(T, mvt, label='mvt cost', color='r')
    plt.plot(T, dmvt, label='dmvt cost', color='r', alpha = 0.25)

    plt.plot(T, time3, label='time cost', color='g')
    plt.plot(T, dtime3, label='dtime cost', color='g', alpha = 0.25)

    plt.plot(T, time1, label='total cost', color='k')
    plt.plot(T, dtime1, label='dtotal cost', color='k', alpha = 0.25)



    plt.legend()
    plt.ylim(0, 25)
    plt.xlim(0, 2.5)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()
    


interactive_plot = interactive(v, d=(.30, .9, .3), Vbelt=(-0.20, .20, .10), alpha=(1, 10, 1), beta=(1, 10, 1), R=(1, 100, 1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=0.9, description='d', max=0.9, min=0.3, step=0.3), FloatSlider(value=0…

# %%
from ipywidgets import interactive

def v(alpha=1, R=1, B=2, d=.9, Vbelt=0):
    plt.figure(1)
    T = np.linspace(-100, 100, 2001)


    Y = R - (R/(1+B*T))
    dYY = B*R/((1+B*T)**2)
    



    mvt = (alpha*d**2)/T -2*alpha*d*Vbelt + alpha*T*Vbelt**2
    dmvt = (-alpha*d**2)/T**2 + alpha*Vbelt**2


    # plt.plot(T, Y)
    # plt.plot(T, dYY)
    #plt.plot(T, mvt)
    # plt.plot(T, dmvt)

    #plt.plot(T, Y+mvt, c='k')
    plt.plot(T, dYY+dmvt, c='k')

    # AY = R - (R/(1+B*T))
    # AdYY = (B*R)/((1+B*T)**2)
    # plt.plot(T, AY, c='r')
    # plt.plot(T, AdYY, c='r')

    plt.ylim(-25, 25)
    plt.xlim(-25, 25)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.axhline(y=R, xmin=0, xmax = 25, ls='--', color='k', lw=0.5)
    plt.show()

interactive_plot = interactive(v, R=(0, 20,.1), B=(0, 10, .1), d=(.30, .9, .3), Vbelt=(-0.20, .20, .10))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(IntSlider(value=1, description='alpha', max=3, min=-1), FloatSlider(value=1.0, descripti…

# %%
# optimal time computation


from ipywidgets import interactive

#def v(d=.9, Vbelt=0, alpha = 1, beta = 1, R=1):

def v(d=.9, Vbelt=0, alpha = 1, beta = 1, R=1):


    # tf = (d/Vopt) * (1 - 0.5*((Vbelt**2)/(Vopt**2)))
    # print(tf)
    fig = plt.figure(constrained_layout = False, figsize=(7.5, 4.5))
    plt.figure(1)
    T = np.linspace(0.01, 2.5, 201)

    mvt = (alpha*(d**2))/T -2*alpha*d*Vbelt + alpha*T*Vbelt**2
    # time3 = R - 1/(beta*T)
    
    dmvt = (-alpha*(d**2))/T**2 + alpha*Vbelt**2
    # dtime3 = -R/(beta*T**2)

    time3 = R - (R/(1+beta*T))
    dtime3 = (beta*R)/((1+beta*T)**2)


    plt.plot(T, mvt, label='mvt cost', color='r')
    plt.plot(T, dmvt, label='dmvt cost', color='r', alpha = 0.25)

    plt.plot(T, time3, label='time cost', color='g')
    plt.plot(T, dtime3, label='dtime cost', color='g', alpha = 0.25)

    plt.plot(T, mvt+time3, label='total cost', color='k')
    plt.plot(T, dmvt+dtime3, label='dtotal cost', color='c')

    a=alpha
    b=beta
    #tttf = np.sqrt(R)*np.sqrt(a)*d/(np.sqrt(b)*(R - a*b*d**2)) - a*d**2/(-R + a*b*d**2)
    #print(tttf)
    #plt.axvline(tttf, 0, 1, ls='--', color='c', lw=0.5)
    print("R=", R, "thingy=", alpha*beta*d**2)


    plt.legend()
    plt.ylim(-5, 100)
    plt.xlim(0, 2.5)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()
    


interactive_plot = interactive(v, d=(.30, .9, .3), Vbelt=(-0.20, .20, .10), alpha=(1, 10, 1), beta=(1, 10, 1), R=(1, 100, 1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=0.9, description='d', max=0.9, min=0.3, step=0.3), FloatSlider(value=0…

# %%
# optimal time computation


from ipywidgets import interactive

#def v(d=.9, Vbelt=0, alpha = 1, beta = 1, R=1):

def v(d=.9, Vbelt=0, alpha = 1, beta = 1, R=1):


    # tf = (d/Vopt) * (1 - 0.5*((Vbelt**2)/(Vopt**2)))
    # print(tf)
    fig = plt.figure(constrained_layout = False, figsize=(7.5, 4.5))
    plt.figure(1)
    T = np.linspace(0.01, 2.5, 201)

    mvt = (alpha*(d**2))/T -2*alpha*d*Vbelt + alpha*T*Vbelt**2
    # time3 = R - 1/(beta*T)
    
    dmvt = (-alpha*(d**2))/T**2 + alpha*Vbelt**2
    # dtime3 = -R/(beta*T**2)

    time3 = R - (R/(1+beta*T))
    dtime3 = (beta*R)/((1+beta*T)**2)


    plt.plot(T, mvt+time3, label='total cost', color='k')
    plt.plot(T, dmvt+dtime3, label='dtotal cost', color='c')

    a=alpha
    b=beta
    #tttf = np.sqrt(R)*np.sqrt(a)*d/(np.sqrt(b)*(R - a*b*d**2)) - a*d**2/(-R + a*b*d**2)
    #print(tttf)
    #plt.axvline(tttf, 0, 1, ls='--', color='c', lw=0.5)
    print("R=", R, "thingy=", alpha*beta*d**2)


    plt.legend()
    plt.ylim(-5, 100)
    plt.xlim(0, 2.5)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()
    


interactive_plot = interactive(v, d=(.30, .9, .3), Vbelt=(-0.20, .20, .10), alpha=(1, 10, 1), beta=(1, 10, 1), R=(1, 100, 1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=0.9, description='d', max=0.9, min=0.3, step=0.3), FloatSlider(value=0…

# %%
### wolfram -a*d**2/x**2+a*v**2+br/(1+bx)**2==0, x>0, b>0, r>0, a>0, d>0

# %%
#theo model
def v(alpha =1, beta=1, d=0.95, vb=0):
    plt.figure(1)
    T = np.linspace(0.05, 5, 201)

    e = (alpha*(d**2))/(T)- 2*alpha*d*vb + alpha*T*vb**2 
    t = beta*T**3


    de = (-(alpha*d**2)/(T**2))+ alpha*vb**2
    dt = 3*beta*T**2

    Y = e + t
    dY = de + dt
    
    plt.plot(T, Y, c='k')
    plt.plot(T, dY, c='k', alpha=0.25)

    plt.plot(T, e, c='r')
    plt.plot(T, t, c='g')
    #plt.plot(T, de, c='r', alpha=0.25)
    #plt.plot(T, dt, c='g', alpha=0.25)

    #plt.scatter(T[np.argmin(Y)], Y[np.argmin(Y)], c='g')
    #print(T[np.argmin(Y)], Y[np.argmin(Y)])

    vopt = np.sqrt(np.sqrt((3*beta*d**2)/alpha))
    tf = d/vopt * (1-(0.25*vb**2)/(vopt**2))

    print("vopt=", vopt, "tf=", tf)
    plt.axvline(tf, 0, 1, ls='--', color='c', lw=0.5)
    

    plt.ylim(-5, 25)
    plt.xlim(0, 2.5)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()

interactive_plot = interactive(v, alpha=(1, 20,1), beta=(1, 20,1), d=(0.30, 0.95, 0.3), vb=(-.20, .20, .10))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(IntSlider(value=1, description='alpha', max=20, min=1), IntSlider(value=1, description='…

# %%
#theo model
def compute_tf(alpha =1, beta=1, d=0.95, vb=0):
    vopt = np.sqrt(np.sqrt((3*beta*d**2)/alpha))
    tf = d/vopt * (1-(0.25*vb**2)/(vopt**2))
    return tf
ttf=compute_tf(alpha =6, beta=1, d=0.95, vb=0)
print(ttf)
# Out:
# 1.1590957183315105

# %%
def modelplot(d=.9, Vbelt=0, alpha = 1, beta = 1, ticks=[[],[],[],[]], xylim=[], xyLabels=[], ssize = [1, 1], colors=[] ):
    ax = plt.gca()
    T = np.linspace(0.01, 2.5, 201)
    CM = (alpha*d**2)/T -2*alpha*d*Vbelt + alpha*T*Vbelt**2
    CT = beta*T
    Vopt = np.sqrt(beta/alpha)
    topt = (d/Vopt) * (1 - 0.5*((Vbelt**2)/(Vopt**2)))
    Copt = (alpha*d**2)/topt -2*alpha*d*Vbelt + alpha*topt*Vbelt**2 + beta*topt

    ax.plot(T, CM, label='$\mathregular{C_E}$', color=colors[0][0], lw=ssize[0], alpha=colors[1][0])
    ax.plot(T, CT, label='$\mathregular{C_T}$', color=colors[0][1], lw=ssize[0], alpha=colors[1][1])
    ax.plot(T, CM+CT, label='$\mathregular{C_E + C_T}$', color=colors[0][2], lw=ssize[0], alpha=colors[1][2])
    plt.scatter(topt, Copt, color=colors[0][2], s=ssize[1]**2, alpha=colors[1][2])
    #plt.annotate("min", (topt-0.1, Copt+2), color='k', fontsize=xyLabels[3]-2)

    ax.set_xlabel(xyLabels[0], fontsize = xyLabels[2])
    ax.set_ylabel(xyLabels[1], fontsize = xyLabels[2])
    ax.set_xlim([xylim[0], xylim[1]])
    ax.set_ylim([xylim[2], xylim[3]])
    ax.spines['top'].set_color("none")
    ax.spines['right'].set_color("none")
    ax.spines['bottom'].set_linewidth(2.5)
    ax.spines['left'].set_linewidth(2.5)
    ax.yaxis.set_label_coords(-0.15,0.5)
    ax.tick_params(width=2.5, labelsize = xyLabels[3]) 
    if ticks[0] != []: 
        ax.set_xticks(ticks[0])
        if ticks[2] != []:
            ax.xaxis.set_major_locator(plt.FixedLocator(ticks[0]))
            ax.xaxis.set_major_formatter(plt.FixedFormatter(ticks[2]))
    if ticks[1] != []: 
        ax.set_yticks(ticks[1])
        if ticks[3] != []:
            ax.yaxis.set_major_locator(plt.FixedLocator(ticks[1]))
            ax.yaxis.set_major_formatter(plt.FixedFormatter(ticks[3]))
    #ax.legend(fontsize=xyLabels[3]-2)
    return ax

def tfplot(d=.9, Vbelt=0, alpha = 1, beta = 1, ticks=[[],[],[],[]], xylim=[], xyLabels=[], ssize = [1, 1], colors=[] ):
    ax = plt.gca()
    T = np.linspace(0.01, 2.5, 201)
    CM = (alpha*d**2)/T -2*alpha*d*Vbelt + alpha*T*Vbelt**2
    CT = beta*T
    Vopt = np.sqrt(beta/alpha)
    topt = (d/Vopt) * (1 - 0.5*((Vbelt**2)/(Vopt**2)))
    Copt = (alpha*d**2)/topt -2*alpha*d*Vbelt + alpha*topt*Vbelt**2 + beta*topt

    # ax.plot(T, CM, label='$\mathregular{C_E}$', color=colors[0][0], lw=ssize[0], alpha=colors[1][0])
    # ax.plot(T, CT, label='$\mathregular{C_T}$', color=colors[0][1], lw=ssize[0], alpha=colors[1][1])
    # ax.plot(T, CM+CT, label='$\mathregular{C_E + C_T}$', color=colors[0][2], lw=ssize[0], alpha=colors[1][2])
    # plt.scatter(topt, Copt, color=colors[0][2], s=ssize[1])
    #plt.annotate("min", (topt-0.1, Copt+2), color='k', fontsize=xyLabels[3]-2)

    # ax.set_xlabel(xyLabels[0], fontsize = xyLabels[2])
    # ax.set_ylabel(xyLabels[1], fontsize = xyLabels[2])
    # ax.set_xlim([xylim[0], xylim[1]])
    # ax.set_ylim([xylim[2], xylim[3]])
    # ax.spines['top'].set_color("none")
    # ax.spines['right'].set_color("none")
    # ax.spines['bottom'].set_linewidth(2.5)
    # ax.spines['left'].set_linewidth(2.5)
    # ax.yaxis.set_label_coords(-0.15,0.5)
    # ax.tick_params(width=2.5, labelsize = xyLabels[3]) 
    # if ticks[0] != []: 
    #     ax.set_xticks(ticks[0])
    #     if ticks[2] != []:
    #         ax.xaxis.set_major_locator(plt.FixedLocator(ticks[0]))
    #         ax.xaxis.set_major_formatter(plt.FixedFormatter(ticks[2]))
    # if ticks[1] != []: 
    #     ax.set_yticks(ticks[1])
    #     if ticks[3] != []:
    #         ax.yaxis.set_major_locator(plt.FixedLocator(ticks[1]))
    #         ax.yaxis.set_major_formatter(plt.FixedFormatter(ticks[3]))
    #ax.legend(fontsize=xyLabels[3]-2)
    return topt, Copt

# %%
for d in [0.3, 0.6, 0.9]: modelplot(d=d, Vbelt=0, alpha=5, beta=3.5, ticks = [[],[],[],[]], xylim=[0.0, 2, 0.0, 25], xyLabels = ['Duration (s)', 'Cost (a.u.)', 12, 12], ssize=[2, 5], colors = [['r', 'g', 'b'], [d, 1, d]])
# plt.plot(tfplot(d=np.linspace(0, 2, 201), Vbelt=0, alpha=5, beta=3.5))

# %%
plt.plot(tfplot(d=np.linspace(0, 2, 201), Vbelt=0, alpha=5, beta=3.5))
# Out:
# /home/david/.local/lib/python3.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# [<matplotlib.lines.Line2D at 0x7f8e8fefd390>,
#  <matplotlib.lines.Line2D at 0x7f8e8fed3ad0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fefd210>,
#  <matplotlib.lines.Line2D at 0x7f8e8fefd2d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fefd4d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fefdbd0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fefd6d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fefdcd0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fefd410>,
#  <matplotlib.lines.Line2D at 0x7f8e8fefded0>,
#  <matplotlib.lines.Line2D at 0x7f8e8ffc6650>,
#  <matplotlib.lines.Line2D at 0x7f8e8fefd350>,
#  <matplotlib.lines.Line2D at 0x7f8e8fefdfd0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fefd550>,
#  <matplotlib.lines.Line2D at 0x7f8e8fefd1d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fefda10>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff07fd0>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff07c10>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff07dd0>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff079d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff07150>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff07410>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff07b10>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff07790>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff071d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff07490>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff07290>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff07a50>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff07590>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff07c90>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff07910>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff07850>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff07ed0>,
#  <matplotlib.lines.Line2D at 0x7f8e9006a0d0>,
#  <matplotlib.lines.Line2D at 0x7f8e9006a710>,
#  <matplotlib.lines.Line2D at 0x7f8e8fef4e50>,
#  <matplotlib.lines.Line2D at 0x7f8e8fef4f90>,
#  <matplotlib.lines.Line2D at 0x7f8e8fef4d90>,
#  <matplotlib.lines.Line2D at 0x7f8e8fef4b90>,
#  <matplotlib.lines.Line2D at 0x7f8e8fef4a10>,
#  <matplotlib.lines.Line2D at 0x7f8e8fef4f10>,
#  <matplotlib.lines.Line2D at 0x7f8e8fef4a50>,
#  <matplotlib.lines.Line2D at 0x7f8e8fef4810>,
#  <matplotlib.lines.Line2D at 0x7f8e8fef4b10>,
#  <matplotlib.lines.Line2D at 0x7f8e8fef4690>,
#  <matplotlib.lines.Line2D at 0x7f8e8fef4190>,
#  <matplotlib.lines.Line2D at 0x7f8e8fef4a90>,
#  <matplotlib.lines.Line2D at 0x7f8e8fef4fd0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fef4e90>,
#  <matplotlib.lines.Line2D at 0x7f8e8fef4310>,
#  <matplotlib.lines.Line2D at 0x7f8e8fef4c50>,
#  <matplotlib.lines.Line2D at 0x7f8e8fef4790>,
#  <matplotlib.lines.Line2D at 0x7f8e8fef4650>,
#  <matplotlib.lines.Line2D at 0x7f8e8fef49d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fef45d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8feecc90>,
#  <matplotlib.lines.Line2D at 0x7f8e8feec750>,
#  <matplotlib.lines.Line2D at 0x7f8e8feec710>,
#  <matplotlib.lines.Line2D at 0x7f8e8feec190>,
#  <matplotlib.lines.Line2D at 0x7f8e8feec310>,
#  <matplotlib.lines.Line2D at 0x7f8e8feece90>,
#  <matplotlib.lines.Line2D at 0x7f8e8feec590>,
#  <matplotlib.lines.Line2D at 0x7f8e8feec910>,
#  <matplotlib.lines.Line2D at 0x7f8e8feec6d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8feec5d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8feecf90>,
#  <matplotlib.lines.Line2D at 0x7f8e8feece50>,
#  <matplotlib.lines.Line2D at 0x7f8e8feecb90>,
#  <matplotlib.lines.Line2D at 0x7f8e8feec550>,
#  <matplotlib.lines.Line2D at 0x7f8e8feec350>,
#  <matplotlib.lines.Line2D at 0x7f8e8feec850>,
#  <matplotlib.lines.Line2D at 0x7f8e8feeca10>,
#  <matplotlib.lines.Line2D at 0x7f8e8feec050>,
#  <matplotlib.lines.Line2D at 0x7f8e8feec3d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8feec490>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff8c3d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff8ca10>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff8cad0>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff8cf50>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff8c7d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff8c8d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff8cd10>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff8c550>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff8c150>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff8ca90>,
#  <matplotlib.lines.Line2D at 0x7f8e8ff8c5d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe9c090>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe9c410>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe9ce10>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe9cbd0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe9cc10>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe9cb50>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe9c2d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe9c690>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe9c650>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe9c4d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe9cd90>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe9c1d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe9c7d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe9c5d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe9c550>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe9c3d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe9cad0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe9cc90>,
#  <matplotlib.lines.Line2D at 0x7f8e8fea8d10>,
#  <matplotlib.lines.Line2D at 0x7f8e8fea8210>,
#  <matplotlib.lines.Line2D at 0x7f8e8fea8610>,
#  <matplotlib.lines.Line2D at 0x7f8e8fea8e10>,
#  <matplotlib.lines.Line2D at 0x7f8e8fea8190>,
#  <matplotlib.lines.Line2D at 0x7f8e8fea8cd0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fea8ad0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fea8c10>,
#  <matplotlib.lines.Line2D at 0x7f8e8fea8810>,
#  <matplotlib.lines.Line2D at 0x7f8e8fea85d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fea8950>,
#  <matplotlib.lines.Line2D at 0x7f8e8fea8f50>,
#  <matplotlib.lines.Line2D at 0x7f8e8fea8ed0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fea8910>,
#  <matplotlib.lines.Line2D at 0x7f8e8fea8b10>,
#  <matplotlib.lines.Line2D at 0x7f8e8fea8050>,
#  <matplotlib.lines.Line2D at 0x7f8e8fea8e90>,
#  <matplotlib.lines.Line2D at 0x7f8e8fea8150>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe91210>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe91b90>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe91790>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe91510>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe91550>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe91650>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe91050>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe91590>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe91290>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe91c10>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe91610>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe91e50>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe91490>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe91d90>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe914d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe913d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe91a10>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe91850>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe91f10>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe96290>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe96a50>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe96c10>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe96cd0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe96d50>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe96250>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe96710>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe96c90>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe963d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe96510>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe96bd0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe968d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe96dd0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe96410>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe960d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe96610>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe969d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe96150>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe96ed0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fdb1890>,
#  <matplotlib.lines.Line2D at 0x7f8e8fdb1210>,
#  <matplotlib.lines.Line2D at 0x7f8e8fdb1350>,
#  <matplotlib.lines.Line2D at 0x7f8e8fdb1b90>,
#  <matplotlib.lines.Line2D at 0x7f8e8fdb10d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fdb1290>,
#  <matplotlib.lines.Line2D at 0x7f8e8fdb1610>,
#  <matplotlib.lines.Line2D at 0x7f8e8fdb1550>,
#  <matplotlib.lines.Line2D at 0x7f8e8fdb1a10>,
#  <matplotlib.lines.Line2D at 0x7f8e8fdb1a50>,
#  <matplotlib.lines.Line2D at 0x7f8e8fdb1310>,
#  <matplotlib.lines.Line2D at 0x7f8e8fdb1790>,
#  <matplotlib.lines.Line2D at 0x7f8e8fdb1d90>,
#  <matplotlib.lines.Line2D at 0x7f8e945c7650>,
#  <matplotlib.lines.Line2D at 0x7f8e947a6ed0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fd2f690>,
#  <matplotlib.lines.Line2D at 0x7f8e8fd2f750>,
#  <matplotlib.lines.Line2D at 0x7f8e8fd2fd90>,
#  <matplotlib.lines.Line2D at 0x7f8e8fd2f910>,
#  <matplotlib.lines.Line2D at 0x7f8e8fd2f610>,
#  <matplotlib.lines.Line2D at 0x7f8e8fd2fb90>,
#  <matplotlib.lines.Line2D at 0x7f8e8fd2f810>,
#  <matplotlib.lines.Line2D at 0x7f8e8fd2f490>,
#  <matplotlib.lines.Line2D at 0x7f8e8fd2f290>,
#  <matplotlib.lines.Line2D at 0x7f8e8fd2f9d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fd2fa50>,
#  <matplotlib.lines.Line2D at 0x7f8e8fd2f8d0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fd2fc50>,
#  <matplotlib.lines.Line2D at 0x7f8e8fd2fc10>,
#  <matplotlib.lines.Line2D at 0x7f8e8fd2ff90>,
#  <matplotlib.lines.Line2D at 0x7f8e8fd2f410>,
#  <matplotlib.lines.Line2D at 0x7f8e8fd2fa10>,
#  <matplotlib.lines.Line2D at 0x7f8e8fd2f550>,
#  <matplotlib.lines.Line2D at 0x7f8e8fd2f390>,
#  <matplotlib.lines.Line2D at 0x7f8e8fd2f110>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe07890>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe07590>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe07fd0>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe07210>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe07990>,
#  <matplotlib.lines.Line2D at 0x7f8e8fe07810>]

# %%
plt.plot(np.linspace(-.20, .2, 5), compute_tf(alpha =6, beta=3.5, d=0.9, vb=np.linspace(-.20, .2, 5)))

# %%
#theo model
def v(alpha =1, beta=1, d=0.95, vb=0):
    fig = plt.figure(constrained_layout = False, figsize=(5, 5))
    T = np.linspace(0.05, 5, 201)

    e = (alpha*(d**2))/(T)- 2*alpha*d*vb + alpha*T*vb**2 
    t = beta*T**3


    de = (-(alpha*d**2)/(T**2))+ alpha*vb**2
    dt = 3*beta*T**2

    Y = e + t
    dY = de + dt
    
    plt.plot(T, Y, c='k', label="total cost")
    #plt.plot(T, dY, c='k', alpha=0.25)

    plt.plot(T, e, c='r', label="effort cost")
    plt.plot(T, t, c='g', label="time cost")
    #plt.plot(T, de, c='r', alpha=0.25)
    #plt.plot(T, dt, c='g', alpha=0.25)

    plt.scatter(T[np.argmin(Y)], Y[np.argmin(Y)], c='k')
    #print(T[np.argmin(Y)], Y[np.argmin(Y)])

    plt.ylim(0, 25)
    plt.xlim(0, 2.5)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.legend()
    plt.show()
v(alpha =8, beta=1, d=0.95, vb=0)

# %%
import sympy as sym

# %%
t = sym.Symbol('t',positive=True,real=True)
a = sym.Symbol('a',positive=True,real=True)
b = sym.Symbol('b',positive=True,real=True)
d = sym.Symbol('d',positive=True,real=True)
R = sym.Symbol('R',positive=True,real=True)
v = sym.Symbol('v',positive=True,real=True)

# %%
# optimal time computation

from ipywidgets import interactive

def v(d=.9, Vbelt=0, alpha = 1, beta = 1, R=1):

    fig = plt.figure(constrained_layout = False, figsize=(5, 5))
    plt.figure(1)
    T = np.linspace(0.01, 2.5, 201)

    CM = (alpha*d**2)/T -4*alpha*d*Vbelt + 4*alpha*T*Vbelt**2
    dCM = (-alpha*d**2)/T**2 + 4*alpha*Vbelt**2
    
    CT = beta*T
    dCT = beta
    dCTplot = np.full((len(T),1), beta)

    
    plt.plot(T, CM, label='mvt cost', color='r')
    plt.plot(T, dCM, label='dmvt cost', color='r', alpha = 0.25)

    plt.plot(T, CT, label='time cost', color='g')
    plt.plot(T, dCTplot, label='dtime cost', color='g', alpha = 0.25)

    plt.plot(T, CM+CT, label='total cost', color='k')
    plt.plot(T, dCM+dCT, label='dtotal cost', color='k', alpha = 0.25)

    # CT2 = R - (R/(1+beta*T))
    # plt.plot(T, CT2, label='time cost', color='g')

    Vopt = np.sqrt(beta/alpha)
    Vopt2 = np.sqrt((alpha*Vbelt**2+beta)/alpha)
    tfexact = np.sqrt((alpha*d**2)/(alpha*Vbelt**2+beta))
    tfapprox = (d/Vopt) * (1 - 0.5*((Vbelt**2)/(Vopt**2)))
    print("tfexact=", tfexact)
    print("tfapprox=", tfapprox, "Vopt=", Vopt, "Vopt2=", Vopt2)
    plt.axvline(tfapprox, 0, 1, ls='--', color='c', lw=0.5)
    plt.axvline(tfexact, 0, 1, ls='--', color='g', lw=1.5)
    plt.legend()
    plt.ylim(0, 25)
    plt.xlim(0, 2.5)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()
    


interactive_plot = interactive(v, d=(.30, .9, .3), Vbelt=(-0.20, .20, .10), alpha=(1, 10, 1), beta=(1, 10, 1), R=(1, 10, 1))
# output = interactive_plot.children[-1]
# output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=0.9, description='d', max=0.9, min=0.3, step=0.3), FloatSlider(value=0…

# %%
from ipywidgets import interactive

def v(d=.9, Vbelt=0, alpha = 1, beta = 1, R=1):

    fig = plt.figure(constrained_layout = False, figsize=(5, 5))
    plt.figure(1)
    T = np.linspace(0.01, 2.5, 201)

    CM = (alpha*d**2)/T -2*alpha*d*Vbelt + alpha*T*Vbelt**2
    dCM = (-alpha*d**2)/T**2 + alpha*Vbelt**2
    
    CT = beta*T
    dCT = beta
    dCTplot = np.full((len(T),1), beta)

    
    plt.plot(T, CM, label='mvt cost', color='r')
    plt.plot(T, dCM, label='dmvt cost', color='r', alpha = 0.25)

    plt.plot(T, CT, label='time cost', color='g')
    plt.plot(T, dCTplot, label='dtime cost', color='g', alpha = 0.25)

    plt.plot(T, CM+CT, label='total cost', color='k')
    plt.plot(T, dCM+dCT, label='dtotal cost', color='k', alpha = 0.25)

    # CT2 = R - (R/(1+beta*T))
    # plt.plot(T, CT2, label='time cost', color='g')

    Vopt = np.sqrt(beta/alpha)
    #tfexact = np.sqrt((alpha*d**2)/(alpha*Vbelt**2+beta))
    tfapprox = (d/Vopt) * (1 - 0.5*((Vbelt**2)/(Vopt**2)))
    #print("tfexact=", tfexact)
    print("tfapprox=", tfapprox, "Vopt=", Vopt)
    plt.axvline(tfapprox, 0, 1, ls='--', color='c', lw=0.5)

    plt.legend()
    plt.ylim(0, 25)
    plt.xlim(0, 2.5)
    plt.axhline(0, 0, 1, ls='--', color='k', lw=0.5)
    plt.show()
    
v(d=(.9), Vbelt=(0), alpha=(5), beta=(5), R=(0))
# Out:
# tfapprox= 0.9 Vopt= 1.0

# %%
def modelplot(d=.9, Vbelt=0, alpha = 1, beta = 1, ticks=[[],[],[],[]], xylim=[], xyLabels=[], ssize = [1, 1], colors=[] ):
    ax = plt.gca()
    T = np.linspace(0.01, 2.5, 201)
    CM = (alpha*d**2)/T -2*alpha*d*Vbelt + alpha*T*Vbelt**2
    CT = beta*T
    Vopt = np.sqrt(beta/alpha)
    topt = (d/Vopt) * (1 - 0.5*((Vbelt**2)/(Vopt**2)))
    Copt = (alpha*d**2)/topt -2*alpha*d*Vbelt + alpha*topt*Vbelt**2 + beta*topt

    ax.plot(T, CM, label='$\mathregular{C_E}$', color=colors[0][0], lw=ssize[0], alpha=colors[1][0])
    ax.plot(T, CT, label='$\mathregular{C_T}$', color=colors[0][1], lw=ssize[0], alpha=colors[1][1])
    ax.plot(T, CM+CT, label='$\mathregular{C_E + C_T}$', color=colors[0][2], lw=ssize[0], alpha=colors[1][2])
    plt.scatter(topt, Copt, color=colors[0][2], s=ssize[1]**2, alpha=colors[1][2])
    #plt.annotate("min", (topt-0.1, Copt+2), color='k', fontsize=xyLabels[3]-2)

    ax.set_xlabel(xyLabels[0], fontsize = xyLabels[2])
    ax.set_ylabel(xyLabels[1], fontsize = xyLabels[2])
    ax.set_xlim([xylim[0], xylim[1]])
    ax.set_ylim([xylim[2], xylim[3]])
    ax.spines['top'].set_color("none")
    ax.spines['right'].set_color("none")
    ax.spines['bottom'].set_linewidth(2.5)
    ax.spines['left'].set_linewidth(2.5)
    ax.yaxis.set_label_coords(-0.15,0.5)
    ax.tick_params(width=2.5, labelsize = xyLabels[3]) 
    if ticks[0] != []: 
        ax.set_xticks(ticks[0])
        if ticks[2] != []:
            ax.xaxis.set_major_locator(plt.FixedLocator(ticks[0]))
            ax.xaxis.set_major_formatter(plt.FixedFormatter(ticks[2]))
    if ticks[1] != []: 
        ax.set_yticks(ticks[1])
        if ticks[3] != []:
            ax.yaxis.set_major_locator(plt.FixedLocator(ticks[1]))
            ax.yaxis.set_major_formatter(plt.FixedFormatter(ticks[3]))
    #ax.legend(fontsize=xyLabels[3]-2)
    return ax
def convert_scale(number): 
    old_min=-.2
    old_max=.2
    new_max=0.2
    new_min=1
    return ((number- old_min) / (old_max - old_min)) * (new_max - new_min) + new_min

    W, H = 34, 53
AXIS_FONTSIZE = 24
TICK_FONTSIZE = 18
LINEWIDTH = 3.5
MARKERSIZE = 12
XAXISLIM = 2

# %%
for d in [0.3, 0.6, 0.9]: ax20 = modelplot(d=d, Vbelt=0, alpha=5, beta=3.5, ticks = [[],[],[],[]], xylim=[0.0, XAXISLIM, 0.0, 25], xyLabels = ['Duration (s)', 'Cost (a.u.)', AXIS_FONTSIZE, TICK_FONTSIZE], ssize=[LINEWIDTH, MARKERSIZE], colors = [['r', 'g', 'b'], [d, 1, d]])

# %%
for vbelt in [-.2, -.1, 0, .1, .2]: ax21 = modelplot(d=.9, Vbelt=vbelt, alpha=5, beta=3.5, ticks = [[],[],[],[]], xylim=[0.0, XAXISLIM, 0.0, 25], xyLabels = ['Duration (s)', 'Cost (a.u.)', AXIS_FONTSIZE, TICK_FONTSIZE], ssize=[LINEWIDTH, MARKERSIZE], colors = [['r', 'g', 'b'], [convert_scale(vbelt), 1, convert_scale(vbelt)]])

# %%
for alpha in range(1, 11, 2): ax30 = modelplot(d=.9, Vbelt=0, alpha=alpha, beta=3.5, ticks = [[],[],[],[]], xylim=[0.0, XAXISLIM, 0.0, 25], xyLabels = ['Duration (s)', 'Cost (a.u.)', AXIS_FONTSIZE, TICK_FONTSIZE], ssize=[LINEWIDTH, MARKERSIZE], colors = [['r', 'g', 'b'], [alpha/10, 1, alpha/10]])

# %%
for beta in range(1, 11, 2): ax31 = modelplot(d=.9, Vbelt=0, alpha=3.5, beta=beta, ticks = [[],[],[],[]], xylim=[0.0, XAXISLIM, 0.0, 25], xyLabels = ['Duration (s)', 'Cost (a.u.)', AXIS_FONTSIZE, TICK_FONTSIZE], ssize=[LINEWIDTH, MARKERSIZE], colors = [['r', 'g', 'b'], [1, beta/10, beta/10]])

# %%
def modelplot(d=.9, Vbelt=0, alpha = 1, beta = 1, ticks=[[],[],[],[]], xylim=[], xyLabels=[], ssize = [1, 1], colors=[] ):
    ax = plt.gca()
    T = np.linspace(0.01, 2.5, 201)
    CM = (alpha*d**2)/T -2*alpha*d*Vbelt + alpha*T*Vbelt**2
    CT = beta*T
    Vopt = np.sqrt(beta/alpha)
    topt = (d/Vopt) * (1 - 0.5*((Vbelt**2)/(Vopt**2)))
    Copt = (alpha*d**2)/topt -2*alpha*d*Vbelt + alpha*topt*Vbelt**2 + beta*topt

    ax.plot(T, CM, label='$\mathregular{C_E}$', color=colors[0][0], lw=ssize[0], alpha=colors[1][0])
    ax.plot(T, CT, label='$\mathregular{C_T}$', color=colors[0][1], lw=ssize[0], alpha=colors[1][1])
    ax.plot(T, CM+CT, label='$\mathregular{C_E + C_T}$', color=colors[0][2], lw=ssize[0], alpha=colors[1][2])
    plt.scatter(topt, Copt, color=colors[0][2], s=ssize[1]**2, alpha=colors[1][2])
    #plt.annotate("min", (topt-0.1, Copt+2), color='k', fontsize=xyLabels[3]-2)

    ax.set_xlabel(xyLabels[0], fontsize = xyLabels[2])
    ax.set_ylabel(xyLabels[1], fontsize = xyLabels[2])
    ax.set_xlim([xylim[0], xylim[1]])
    ax.set_ylim([xylim[2], xylim[3]])
    ax.spines['top'].set_color("none")
    ax.spines['right'].set_color("none")
    ax.spines['bottom'].set_linewidth(2.5)
    ax.spines['left'].set_linewidth(2.5)
    ax.yaxis.set_label_coords(-0.15,0.5)
    ax.tick_params(width=2.5, labelsize = xyLabels[3]) 
    if ticks[0] != []: 
        ax.set_xticks(ticks[0])
        if ticks[2] != []:
            ax.xaxis.set_major_locator(plt.FixedLocator(ticks[0]))
            ax.xaxis.set_major_formatter(plt.FixedFormatter(ticks[2]))
    if ticks[1] != []: 
        ax.set_yticks(ticks[1])
        if ticks[3] != []:
            ax.yaxis.set_major_locator(plt.FixedLocator(ticks[1]))
            ax.yaxis.set_major_formatter(plt.FixedFormatter(ticks[3]))
    #ax.legend(fontsize=xyLabels[3]-2)
    return ax

def topt(d=.9, Vbelt=0, alpha = 1, beta = 1):
    T = np.linspace(0.01, 2.5, 201)
    CM = (alpha*d**2)/T -2*alpha*d*Vbelt + alpha*T*Vbelt**2
    CT = beta*T
    Vopt = np.sqrt(beta/alpha)
    topt = (d/Vopt) * (1 - 0.5*((Vbelt**2)/(Vopt**2)))
    Copt = (alpha*d**2)/topt -2*alpha*d*Vbelt + alpha*topt*Vbelt**2 + beta*topt
    return topt


for vbelt in [-.2, -.1, 0, .1, .2]: ax21 = modelplot(d=.9, Vbelt=vbelt, alpha=5, beta=3.5, ticks = [[],[],[],[]], xylim=[0.0, XAXISLIM, 0.0, 25], xyLabels = ['Duration (s)', 'Cost (a.u.)', AXIS_FONTSIZE, TICK_FONTSIZE], ssize=[LINEWIDTH, MARKERSIZE], colors = [['r', 'g', 'b'], [convert_scale(vbelt), 1, convert_scale(vbelt)]])

# %%
topt(d=.9, Vbelt=0, alpha = 10, beta = 3.5)
# Out:
# 1.52127765851133

# %%
def topt(d=.9, Vbelt=0, alpha = 1, beta = 1):
    Vopt = np.sqrt(beta/alpha)
    topt = (d/Vopt) * (1 - 0.5*((Vbelt**2)/(Vopt**2)))
    return topt

x, y, z = [], [], []

#from mpl_toolkits import mplot3d
ax = plt.axes(projection='3d')
for alpha in np.linspace(1, 11, 20):
    for beta in np.linspace(1, 11, 20):
        x.append(alpha)
        y.append(beta)
        z.append(topt(d=.9, Vbelt=0, alpha=alpha, beta=beta))

ax.plot_trisurf(x, y, z)

ax.set_xlabel('alpha')
ax.set_ylabel('beta')
ax.set_zlabel('tf')
ax.view_init(30, 75)
